# %%
import TTC_helper

# %%
route_506 = TTC_helper.TTC_line('506')

# %%
route_506.getDelayRecord('2022')
# Out:
#              Date Line   Time       Day                Location  \
# 20     2022-01-01  506  09:04  Saturday  HOWARD PARK AND RONCES
# 23     2022-01-01  506  09:29  Saturday   COLLEGE AND LANSDOWNE
# 30     2022-01-01  506  11:54  Saturday   COLLEGE AND LANSDOWNE
# 32     2022-01-01  506  12:38  Saturday   LANSDOWNE AND COLLEGE
# 36     2022-01-01  506  13:43  Saturday            MAIN STATION
# ...           ...  ...    ...       ...                     ...
# 17596  2022-12-30  506  18:16    Friday     MAIN STREET STATION
# 17601  2022-12-30  506  21:52    Friday          HIGH PARK LOOP
# 17606  2022-12-30  506  01:33    Friday  QUEEN AND RONCESVALLES
# 17612  2022-12-31  506  07:35  Saturday    BROADVIEW AND GERRAD
# 17620  2022-12-31  506  12:16  Saturday    CASTLE FRANK STATION
#
#                  Incident Min Delay Min Gap Bound Vehicle         lat  \
# 20             Operations         9      18   NaN       0         NaN
# ...

# %%
route_506.getDelayRecord('2024')
# Out:
#              Date Line   Time      Day                Location  \
# 8      2024-01-01  506  04:53   Monday        RONCESVALLE YARD
# 13     2024-01-01  506  05:05   Monday       RONCESVALLES YARD
# 21     2024-01-01  506  05:31   Monday       GERRARD AND LOGAN
# 24     2024-01-01  506  05:51   Monday       RONCESVALLES YARD
# 52     2024-01-01  506  21:22   Monday     DUNDAS AND STERLING
# ...           ...  ...    ...      ...                     ...
# 14186  2024-12-31  506  13:01  Tuesday       GERRARD AND RIVER
# 14189  2024-12-31  506  13:14  Tuesday  HOWARD PARK AND PARKSI
# 14192  2024-12-31  506  14:10  Tuesday       GERRARD AND RIVER
# 14198  2024-12-31  506  21:07  Tuesday      GERRARD AND SUMACH
# 14202  2024-12-31  506  22:32  Tuesday      CARLTON AND JARVIS
#
#                  Incident Min Delay Min Gap Bound Vehicle         lat  \
# 8           General Delay        13      28     E    4408         NaN
# ...

# %%
route_506.displayDensityMap('2024')

# %%
route_509 = TTC_helper.TTC_line('509')

# %%
route_509.getDelayRecord('2022')
# Out:
#              Date Line   Time       Day                Location  \
# 65     2022-01-01  509  21:38  Saturday                CNE LOOP
# 109    2022-01-02  509  14:30    Sunday                CNE LOOP
# 136    2022-01-02  509  21:21    Sunday                CNE LOOP
# 144    2022-01-02  509  01:21    Sunday         EXHIBITION LOOP
# 157    2022-01-03  509  08:11    Monday    QUEENS QUAY AND YORK
# ...           ...  ...    ...       ...                     ...
# 17566  2022-12-29  509  23:00  Thursday         EXHIBITION LOOP
# 17580  2022-12-30  509  11:58    Friday           UNION STATION
# 17633  2022-12-31  509  19:08  Saturday     COXWELL AND GERRARD
# 17646  2022-12-31  509  00:05  Saturday    QUEENS QUAY AND YORK
# 17648  2022-12-31  509  01:12  Saturday  QUEENS QUAY AND HARBOU
#
#                     Incident Min Delay Min Gap Bound Vehicle         lat  \
# 65     Cleaning - Unsanitary         9      18     E    4468         NaN
# ...

# %%
route_509.displayDensityMap('2022')
