# %%
import numpy as np
import seaborn as sns
import pandas as pd
import os

from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import r2_score
from sklearn.metrics import root_mean_squared_error as rmse

# %%
by_day_data = '../data/schedule_data/processed_data/by_day_with_count'
by_day_data = by_day_data
dataframes = [pd.read_csv(os.path.join(by_day_data,x)) for x in os.listdir(by_day_data) if x[-4:] == '.csv']
daily_df = pd.concat(dataframes, ignore_index=True)
daily_df['date'] = daily_df['date'].apply(lambda x: pd.Timestamp(x))
daily_df = daily_df[daily_df['date'] < pd.Timestamp('2025-09-01')]

daily_df = daily_df.rename(columns={'delay time (5,19]':'dt_short', 'delay time (19,120]':'dt_long', 'EB/WB':'dir'})

# %%
daily_df.head()
# Out:
#         date dir                           stop  bunch  gap  dt_short  \
# 0 2025-01-01   E                   Woodfield Rd     12    7         3
# 1 2025-01-01   E                   Blackburn St      0    0         0
# 2 2025-01-01   W                 High Park Loop      0    0         0
# 3 2025-01-01   E  Gerrard St East at Beaton Ave     14   10         4
# 4 2025-01-01   E               Roncesvalles Ave      1    1         2
#
#    dt_long  No. of Veh  Run time (min)  Term time (min)  Avg. spd (km/h)  \
# 0        0        16.4           153.4             10.6            11.92
# 1        0        16.4           153.4             10.6            11.92
# 2        0        16.4           153.4             10.6            11.92
# 3        0        16.4           153.4             10.6            11.92
# 4        0        16.4           153.4             10.6            11.92
#
#    RT dist (km)  Interruption
# 0         30.13             0
# 1         30.13             0
# 2         30.13             0
# 3         30.13             0
# 4         30.13             0

# %%
daily_df[daily_df.stop == 'Main St'].stop.unique()
# Out:
# array(['Main St'], dtype=object)

# %%
daily_df.date = daily_df.date.apply(pd.Timestamp)

# %%
# I want to add daily weather data. 
weather=pd.read_csv('../data/raw_data/Weatherstats_data/weatherstats_toronto_daily.csv')
#drop columns that consist exclusively of NaNs
weather.dropna(axis=1, how='all', inplace=True)
#Convert date from string to datetime type
weather.date = weather.date.apply(pd.Timestamp)

#fill remainder of the NaNs with '0'
weather.fillna(0, inplace=True)

columns = weather.columns
#the following columns have a deterministic relationship with the temperature so we are dropping them
columns = [x for x in columns if 'degdays' not in x]

# Choosing avg stats vs max/min stats
columns = [x for x in columns if 'max' not in x and 'min' not in x]
# Removing 'hourly data'
columns = [x for x in columns if 'hourly' not in x]
# Picking one time format
columns = [x for x in columns if 'sunrise_f' != x and 'sunset_f' != x]
columns = [x for x in columns if 'unixtime' not in x]
# Picking station pressure vs sea pressure
columns = [x for x in columns if 'avg_pressure_sea' != x]


weather['sunrise_hhmm'] = weather['sunrise_hhmm'].apply(pd.Timedelta)
weather['sunset_hhmm'] = weather['sunset_hhmm'].apply(pd.Timedelta)

weather = weather[columns]

# %%
first_date = daily_df['date'].min()
last_date = daily_df['date'].max()
weather = weather[weather['date'].between(first_date,last_date)]
weather.head()
# Out:
#           date  avg_temperature  avg_relative_humidity  avg_dew_point  \
# 174 2025-08-31            16.39                   57.5            9.1
# 175 2025-08-30            15.00                   58.5            7.5
# 176 2025-08-29            13.55                   64.5            6.0
# 177 2025-08-28            14.95                   73.5           11.8
# 178 2025-08-27            17.00                   58.0            6.7
#
#      avg_wind_speed  wind_gust_dir_10s  avg_pressure_station  avg_visibility  \
# 174             8.5                0.0                100.36           24100
# 175            13.0               31.0                 99.96           24100
# 176            19.5               31.0                 99.73           24100
# 177            17.5               32.0                 99.53           18500
# 178            19.5               26.0                 99.86           24100
#
#      avg_health_index  precipitation  rain  snow  snow_on_ground  \
# 174               2.0            0.0   0.0   0.0             0.0
# 175               2.0            0.0   0.0   0.0             0.0
# 176               1.7            0.0   0.0   0.0             0.0
# 177               2.2            5.4   5.4   0.0             0.0
# 178               2.1            0.0   0.0   0.0             0.0
#
#        sunrise_hhmm     sunset_hhmm  daylight  avg_cloud_cover_8
# 174 0 days 06:40:00 0 days 19:55:00     13.25                2.0
# 175 0 days 06:39:00 0 days 19:57:00     13.30                3.5
# 176 0 days 06:38:00 0 days 19:59:00     13.35                4.0
# 177 0 days 06:36:00 0 days 20:00:00     13.40                4.0
# 178 0 days 06:35:00 0 days 20:02:00     13.45                3.0

# %%
daily_df = pd.merge(daily_df, weather, on='date')

# %%
daily_df.head()
# Out:
#         date dir                           stop  bunch  gap  dt_short  \
# 0 2025-01-01   E                   Woodfield Rd     12    7         3
# 1 2025-01-01   E                   Blackburn St      0    0         0
# 2 2025-01-01   W                 High Park Loop      0    0         0
# 3 2025-01-01   E  Gerrard St East at Beaton Ave     14   10         4
# 4 2025-01-01   E               Roncesvalles Ave      1    1         2
#
#    dt_long  No. of Veh  Run time (min)  Term time (min)  ...  avg_visibility  \
# 0        0        16.4           153.4             10.6  ...           16900
# 1        0        16.4           153.4             10.6  ...           16900
# 2        0        16.4           153.4             10.6  ...           16900
# 3        0        16.4           153.4             10.6  ...           16900
# 4        0        16.4           153.4             10.6  ...           16900
#
#    avg_health_index  precipitation  rain  snow  snow_on_ground  \
# 0               1.6            0.7   0.7   0.0             0.0
# 1               1.6            0.7   0.7   0.0             0.0
# 2               1.6            0.7   0.7   0.0             0.0
# 3               1.6            0.7   0.7   0.0             0.0
# 4               1.6            0.7   0.7   0.0             0.0
#
#      sunrise_hhmm     sunset_hhmm  daylight  avg_cloud_cover_8
# 0 0 days 07:51:00 0 days 16:51:00       9.0                7.0
# 1 0 days 07:51:00 0 days 16:51:00       9.0                7.0
# 2 0 days 07:51:00 0 days 16:51:00       9.0                7.0
# 3 0 days 07:51:00 0 days 16:51:00       9.0                7.0
# 4 0 days 07:51:00 0 days 16:51:00       9.0                7.0
#
# [5 rows x 29 columns]

# %%
# Fill na values with 0
daily_df.fillna(0, inplace=True)

# %%
features = ['dir', 'bunch', 'gap', 'Interruption']+weather.columns.to_list()
targets = [x for x in daily_df.columns if 'dt_' in x]

# %%
corr_matrix = daily_df[features+targets].select_dtypes(np.number).corr()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,14))
sns.heatmap(corr_matrix, 
            annot=True, 
            cmap='coolwarm', 
            center=0,
            fmt='.2f')
plt.show()

# %% [markdown]
# Most of these columns are either essentially repeats of other columns, or totally uncorrelated, except for the following features:
# - Bunch, Gap, Interruption, avg_temperature, avg_wind_speed, avg_visibility, avg_health_index, rain, snow_on_ground, daylight
#
# Interestingly, factors like windspeed seem to not play any role on the data.
#
# Lets build a model around these features. First let's see a truncated version of the correlation matrix with only these features.

# %%
features = ['bunch', 'gap','avg_temperature', 'avg_wind_speed', 'precipitation', 'avg_visibility', 'avg_health_index', 'rain', 'snow_on_ground', 'daylight']
targets = [x for x in daily_df.columns if 'dt_' in x]

corr_matrix = daily_df[features+targets].corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f');

# %%
for dt in ['dt_short', 'dt_long']:
    plt.figure(figsize=(20,3))
    sns.lineplot(data=daily_df, x='date', y=dt)
    plt.title(dt)
    plt.show()

plt.figure(figsize=(20,3))
sns.lineplot(data=daily_df, x='date', y='bunch')
plt.title('bunch')
plt.show()

# %% [markdown]
# Some of the feature of the long term weight can be explained by snowfall.

# %%
plt.figure(figsize=(20,3))
sns.lineplot(data=daily_df, x='date', y='snow_on_ground')
plt.show()

# %% [markdown]
# Another region of 'spikes' corresponds to some of the hottest days of the year.

# %%
plt.figure(figsize=(20,3))
sns.lineplot(data=daily_df, x='date', y='daylight')
plt.show()

# %% [markdown]
# The ACF and PACF plots show no strong correlation between bunch events per day.

# %%
def count_feature(date, feature, df):
    if len(df[df['date'] == date][feature].tolist())==0:
        return 0
    else:
        return sum(df[df['date'] == date][feature])

bunch_events = []
start_date = daily_df.date.min()
end_date = daily_df.date.max()
timedelta = (end_date - start_date).days
for delta in range(timedelta):
    bunch_events.append(count_feature(start_date+pd.Timedelta(days=delta), 'bunch', daily_df))

bunch_events = np.array(bunch_events)

# %%
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
plot_acf(bunch_events)
plt.show()
plot_pacf(bunch_events)
plt.show()

# %% [markdown]
# We use xgboost since it's a very flexible model that generalizes well. According to (https://stats.stackexchange.com/questions/338904/measures-of-ordinal-classification-error-for-ordinal-regression)[this post on Cross Validated], RMSE is the best measure of performance for ordinal classification when the classes are reasonably balanced, and MAE should not be used. Note that 'dt_long' is *not* balanced, and so we will have to come to an analysis of this with a different metric.

# %%
# Let's try xgboost since it is a very flexible model
import xgboost as xgb
# First turn stop into a categorical feature.
daily_df['stop']=daily_df['stop'].astype('category')
daily_df['dir']=daily_df['dir'].astype('category')

loss = dict()
R2_score = dict()
features = ['bunch', 'gap', 'avg_temperature', 'avg_wind_speed', 'avg_visibility', 'avg_health_index', 'rain',
            'snow_on_ground',
            'daylight', 'dir', 'stop']

tss = TimeSeriesSplit(n_splits=5, test_size=30)
for target in ['dt_short', 'dt_long']:
    for idx, (tss_train, tss_test) in enumerate(tss.split(daily_df, daily_df.date)):
        df_train = daily_df.iloc[tss_train]
        df_test = daily_df.iloc[tss_test]

        model = xgb.XGBRegressor(objective='reg:squarederror',
                                n_estimators=200,
                                enable_categorical=True,
                                learning_rate=0.1,
                                max_depth=10,
                                reg_alpha=2,
                                reg_lambda=0,
                                seed=37)

        X_train = df_train[features]
        y_train = df_train[target]
        X_test = df_test[features]
        y_test = df_test[target]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        R2_score[target,idx] = r2_score(y_test, y_pred)
        loss[target,idx] = rmse(y_test, y_pred)

for dt in ['dt_short', 'dt_long']:
    print(f'{dt} rmse mean: {np.array([val for key,val in loss.items() if key[0] == dt]).mean()}')
    print(f'{dt} rmse std: {np.array([val for key,val in loss.items() if key[0] == dt]).std()}')
    print(f'{dt} average R^2 score: {np.array([val for key,val in R2_score.items() if key[0] == dt]).mean()}')
    print(f'{dt} R^2 score std: {np.array([val for key,val in R2_score.items() if key[0] == dt]).std()}\n')
# Out:
# dt_short rmse mean: 4.208203411102295
# dt_short rmse std: 1.6497594241518674
# dt_short average R^2 score: 0.8898298144340515
# dt_short R^2 score std: 0.09350544237250284
#
# dt_long rmse mean: 2.407963824272156
# dt_long rmse std: 0.6703722825969604
# dt_long average R^2 score: 0.31648370027542116
# dt_long R^2 score std: 0.4814686746721854

# %% [markdown]
# We're going to try to use Shapley values to do some analysis on the feature set, mimicking [Wendy's analysis on the effect of gender on pay](https://www.kaggle.com/code/manwaicheung/gender-pay-gap). One factor that we want to isolate is the direction of the streetcar.

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},l=Symbol.for("react.portal"),u=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:l,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=u.T,n=o.p;try{if(u.T=null,o.p=2,e)return e()}finally{u.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return u.H.useFormState(e,t,n)},t.useFormStatus=function(){return u.H.useHostTransitionStatus()},t.version="19.2.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function l(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function u(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %%
df_filter = dict()
y_filter = dict()
X_filter= dict()
for target in ['dt_short', 'dt_long']:
    for dir in daily_df.dir.unique():
        df_filter[str(dir), target] = daily_df[(daily_df['dir']==dir)]
        X_filter[str(dir), target] = df_filter[str(dir), target][[x for x in features]]
        y_filter[str(dir), target] = df_filter[str(dir), target][target]

# %%
model_filter = dict()
for key in df_filter.keys():
    model_filter[key] = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=200,
    learning_rate=0.1,
    enable_categorical=True,
    max_depth=10,
    reg_alpha=2,
    reg_lambda=0,
    seed=37)
    model_filter[key].fit(X_filter[key], y_filter[key])

# %%
explainer_filter = dict()
shap_filter = dict()
for key in df_filter.keys():
    explainer_filter[key] = shap.Explainer(model_filter[key])
    shap_filter[key] = explainer_filter[key](X_filter[key])

# %% [markdown]
# Lets first see a waterfall plot to see how our function compares to the baseline

# %%
for key in df_filter.keys():
    shap.plots.bar(shap_filter[key], show=False)
    plt.title(str(key))
    plt.show()

# %% [markdown]
# That gap seems to be so dominant is very suspicious, especially since gapping events are defined as gaps between streetcars that are at least 19 minutes long. Therefore, we rerun the model without it.

# %%
loss = dict()
R2_score = dict()
features = ['bunch', 'avg_wind_speed', 'avg_visibility', 'avg_health_index', 'rain', 'snow_on_ground', 'daylight', 'dir', 'stop']

tss = TimeSeriesSplit(n_splits=5, test_size=30)
for target in ['dt_short', 'dt_long']:
    for idx, (tss_train, tss_test) in enumerate(tss.split(daily_df, daily_df.date)):
        df_train = daily_df.iloc[tss_train]
        df_test = daily_df.iloc[tss_test]

        model = xgb.XGBRegressor(objective='reg:squarederror',
                                n_estimators=200,
                                enable_categorical=True,
                                learning_rate=0.1,
                                max_depth=10,
                                reg_lambda=2,
                                reg_alpha=0,
                                seed=37)

        X_train = df_train[features]
        y_train = df_train[target]
        X_test = df_test[features]
        y_test = df_test[target]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        R2_score[target,idx] = r2_score(y_test, y_pred)
        loss[target,idx] = rmse(y_test, y_pred)
for dt in ['dt_short', 'dt_long']:
    print(f'{dt} rmse mean: {np.array([val for key,val in loss.items() if key[0] == dt]).mean()}')
    print(f'{dt} rmse std: {np.array([val for key,val in loss.items() if key[0] == dt]).std()}')
    print(f'{dt} average R^2 score: {np.array([val for key,val in R2_score.items() if key[0] == dt]).mean()}')
    print(f'{dt} R^2 score std: {np.array([val for key,val in R2_score.items() if key[0] == dt]).std()}\n')

print(R2_score)
# Out:
# dt_short rmse mean: 3.302093267440796
# dt_short rmse std: 0.8985309575776563
# dt_short average R^2 score: 0.9374592661857605
# dt_short R^2 score std: 0.03615963235395238
#
# dt_long rmse mean: 1.8391153812408447
# dt_long rmse std: 0.5302963191142316
# dt_long average R^2 score: 0.5443824529647827
# dt_long R^2 score std: 0.4357203707167961
#
# {('dt_short', 0): 0.8709499835968018, ('dt_short', 1): 0.9564191102981567, ('dt_short', 2): 0.9317482113838196, ('dt_short', 3): 0.9517672061920166, ('dt_short', 4): 0.9764118194580078, ('dt_long', 0): 0.6846076250076294, ('dt_long', 1): -0.3147411346435547, ('dt_long', 2): 0.7829882502555847, ('dt_long', 3): 0.6864687204360962, ('dt_long', 4): 0.882588803768158}

# %% [markdown]
# Let us do some hyperparameter tuning on this model.

# %%
loss = dict()
R2_score = dict()
features = ['bunch', 'avg_wind_speed', 'avg_visibility', 'avg_health_index', 'rain', 'snow_on_ground', 'daylight', 'dir', 'stop']

tss = TimeSeriesSplit(n_splits=5, test_size=30)
target = 'dt_short'
lambda_vals = [0,1,3,5,10,20]
alpha_vals = [0,1,3,5,10,20]
depth_vals = [5,10,15,20]
est_vals = [100,200]

params = dict()
for l in lambda_vals:
    for a in alpha_vals:
        for d in depth_vals:
            for n in est_vals:
                params[l,a,d,n] = (l,a,d,n)

for param in params.keys():
    for idx, (tss_train, tss_test) in enumerate(tss.split(daily_df, daily_df.date)):
        df_train = daily_df.iloc[tss_train]
        df_test = daily_df.iloc[tss_test]

        model = xgb.XGBRegressor(objective='reg:squarederror',
                                n_estimators=param[3],
                                enable_categorical=True,
                                learning_rate=0.1,
                                max_depth=param[2],
                                reg_lambda=param[0],
                                reg_alpha=param[1],
                                seed=37)

        X_train = df_train[features]
        y_train = df_train[target]
        X_test = df_test[features]
        y_test = df_test[target]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        R2_score[param,idx] = r2_score(y_test, y_pred)
        loss[param,idx] = rmse(y_test, y_pred)

# %%
for param in params.keys():
    print(f'param: {param}')
    print(f'{target} rmse mean: {np.array([val for key,val in loss.items() if key[0] == param]).mean()}')
    print(f'{target} rmse std: {np.array([val for key,val in loss.items() if key[0] == param]).std()}')

# %%
best_loss = np.inf
best_R2 = 0
best_loss_param = (0,0,0,0)
best_R2_param = (0,0,0,0)
for param in params.keys():
    curr_loss = np.array([loss[param, idx] for idx in range(5)]).mean()
    curr_R2 = np.array([R2_score[param, idx] for idx in range(5)]).mean()
    if curr_loss < best_loss:
        best_loss = loss[param, idx]
        best_loss_param = param
    if curr_R2 > best_R2:
        best_R2 = curr_R2
        best_R2_param = param

print(best_loss, best_loss_param, best_R2, best_R2_param)
print([loss[best_loss_param, idx] for idx in range(5)])
print([R2_score[best_loss_param, idx] for idx in range(5)])

print([loss[best_R2_param, idx] for idx in range(5)])
print([R2_score[best_R2_param, idx] for idx in range(5)])

# %%
loss = dict()
R2_score = dict()
features = ['bunch', 'avg_wind_speed', 'avg_visibility', 'avg_health_index', 'rain', 'snow_on_ground', 'daylight', 'dir', 'stop']

tss = TimeSeriesSplit(n_splits=5, test_size=30)
target = 'dt_long'
lambda_vals = [0,1,3,5,10,20]
alpha_vals = [0,1,3,5,10,20]
depth_vals = [5,10,15,20]
est_vals = [100,200]

params = dict()
for l in lambda_vals:
    for a in alpha_vals:
        for d in depth_vals:
            for n in est_vals:
                params[l,a,d,n] = (l,a,d,n)

for param in params.keys():
    for idx, (tss_train, tss_test) in enumerate(tss.split(daily_df, daily_df.date)):
        df_train = daily_df.iloc[tss_train]
        df_test = daily_df.iloc[tss_test]

        model = xgb.XGBRegressor(objective='reg:squarederror',
                                n_estimators=param[3],
                                enable_categorical=True,
                                learning_rate=0.1,
                                max_depth=param[2],
                                reg_lambda=param[0],
                                reg_alpha=param[1],
                                seed=37)

        X_train = df_train[features]
        y_train = df_train[target]
        X_test = df_test[features]
        y_test = df_test[target]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        R2_score[param,idx] = r2_score(y_test, y_pred)
        loss[param,idx] = rmse(y_test, y_pred)

# %%
for param in params.keys():
    print(f'param: {param}')
    print(f'{target} rmse mean: {np.array([val for key,val in loss.items() if key[0] == param]).mean()}')
    print(f'{target} rmse std: {np.array([val for key,val in loss.items() if key[0] == param]).std()}')
    print(f'{target} average R^2 score: {np.array([val for key,val in R2_score.items() if key[0] == param]).mean()}')
    print(f'{target} R^2 score std: {np.array([val for key,val in R2_score.items() if key[0] == param]).std()}\n')
# Out:
# param: (0, 0, 5, 100)
# dt_long rmse mean: 1.7252504348754882
# dt_long rmse std: 0.2781282180657814
# dt_long average R^2 score: 0.632954478263855
# dt_long R^2 score std: 0.23971269318974814
#
# param: (0, 0, 5, 200)
# dt_long rmse mean: 1.8648076057434082
# dt_long rmse std: 0.4046840016104351
# dt_long average R^2 score: 0.5415695309638977
# dt_long R^2 score std: 0.3616621321223544
#
# param: (0, 0, 10, 100)
# dt_long rmse mean: 2.0974550008773805
# dt_long rmse std: 0.4634894319738902
# dt_long average R^2 score: 0.41839555501937864
# dt_long R^2 score std: 0.4627455119015455
#
# param: (0, 0, 10, 200)
# dt_long rmse mean: 2.1260061502456664
# dt_long rmse std: 0.5170357853622795
# dt_long average R^2 score: 0.39221179485321045
# dt_long R^2 score std: 0.5119666636688571
#
# param: (0, 0, 15, 100)
# dt_long rmse mean: 2.1001981258392335
# dt_long rmse std: 0.5857541566047397
# dt_long average R^2 score: 0.5505486249923706
# dt_long R^2 score std: 0.20638948419069172
#
# param: (0, 0, 15, 200)
# dt_long rmse mean: 2.0995712757110594
# dt_long rmse std: 0.5861350526335668
# dt_long average R^2 score: 0.5506339192390441
# dt_long R^2 score std: 0.20711049162101788
#
# param: (0, 0, 20, 100)
# dt_long rmse mean: 2.2106102228164675
# dt_long rmse std: 0.6271439240937416
# dt_long average R^2 score: 0.499154269695282
# dt_long R^2 score std: 0.2387351313722092
#
# param: (0, 0, 20, 200)
# dt_long rmse mean: 2.2104637145996096
# dt_long rmse std: 0.6271942018289063
# dt_long average R^2 score: 0.49922832250595095
# dt_long R^2 score std: 0.23869236846467837
#
# param: (0, 1, 5, 100)
# dt_long rmse mean: 1.8414010047912597
# dt_long rmse std: 0.32623516997851265
# dt_long average R^2 score: 0.6133893132209778
# dt_long R^2 score std: 0.2142247476637596
#
# param: (0, 1, 5, 200)
# dt_long rmse mean: 2.0262547016143797
# dt_long rmse std: 0.4849484436057694
# dt_long average R^2 score: 0.4990139722824097
# dt_long R^2 score std: 0.39910236208889116
#
# param: (0, 1, 10, 100)
# dt_long rmse mean: 1.710530686378479
# dt_long rmse std: 0.21867652541235647
# dt_long average R^2 score: 0.6304643273353576
# dt_long R^2 score std: 0.21327933445593358
#
# param: (0, 1, 10, 200)
# dt_long rmse mean: 1.7179286003112793
# dt_long rmse std: 0.238131416063043
# dt_long average R^2 score: 0.6267904043197632
# dt_long R^2 score std: 0.21242336044266405
#
# param: (0, 1, 15, 100)
# dt_long rmse mean: 1.984377908706665
# dt_long rmse std: 0.6764243236542096
# dt_long average R^2 score: 0.5604092359542847
# dt_long R^2 score std: 0.32844833518666133
#
# param: (0, 1, 15, 200)
# dt_long rmse mean: 1.9754408121109008
# dt_long rmse std: 0.6736425120925466
# dt_long average R^2 score: 0.5638625144958496
# dt_long R^2 score std: 0.32741736915416414
#
# param: (0, 1, 20, 100)
# dt_long rmse mean: 1.9520418167114257
# dt_long rmse std: 0.6413419269550017
# dt_long average R^2 score: 0.5990682601928711
# dt_long R^2 score std: 0.2426827746509414
#
# param: (0, 1, 20, 200)
# dt_long rmse mean: 1.9505691289901734
# dt_long rmse std: 0.6413159558493856
# dt_long average R^2 score: 0.5998157620429992
# dt_long R^2 score std: 0.24175361570672904
#
# param: (0, 3, 5, 100)
# dt_long rmse mean: 1.8322576761245728
# dt_long rmse std: 0.23548030617349877
# dt_long average R^2 score: 0.6246419191360474
# dt_long R^2 score std: 0.1775972898958409
#
# param: (0, 3, 5, 200)
# dt_long rmse mean: 1.9930810451507568
# dt_long rmse std: 0.30880096669060175
# dt_long average R^2 score: 0.5307284951210022
# dt_long R^2 score std: 0.2832746695172291
#
# param: (0, 3, 10, 100)
# dt_long rmse mean: 1.695889949798584
# dt_long rmse std: 0.43542627822793795
# dt_long average R^2 score: 0.6280040860176086
# dt_long R^2 score std: 0.29241163638053697
#
# param: (0, 3, 10, 200)
# dt_long rmse mean: 1.6867019891738892
# dt_long rmse std: 0.4634753737859894
# dt_long average R^2 score: 0.6228710055351258
# dt_long R^2 score std: 0.3134195303803474
#
# param: (0, 3, 15, 100)
# dt_long rmse mean: 1.7534523010253906
# dt_long rmse std: 0.6679611420249025
# dt_long average R^2 score: 0.6596676588058472
# dt_long R^2 score std: 0.26230597092964897
#
# param: (0, 3, 15, 200)
# dt_long rmse mean: 1.7352386951446532
# dt_long rmse std: 0.6695288987495198
# dt_long average R^2 score: 0.6640612840652466
# dt_long R^2 score std: 0.26421678251272557
#
# param: (0, 3, 20, 100)
# dt_long rmse mean: 1.7746286869049073
# dt_long rmse std: 0.6633871991666723
# dt_long average R^2 score: 0.67100750207901
# dt_long R^2 score std: 0.20981011172217204
#
# param: (0, 3, 20, 200)
# dt_long rmse mean: 1.7658309936523438
# dt_long rmse std: 0.6530405388106345
# dt_long average R^2 score: 0.6742164850234985
# dt_long R^2 score std: 0.2055456405041369
#
# param: (0, 5, 5, 100)
# dt_long rmse mean: 1.7492788553237915
# dt_long rmse std: 0.22397354660657467
# dt_long average R^2 score: 0.6530008912086487
# dt_long R^2 score std: 0.1667067399469237
#
# param: (0, 5, 5, 200)
# dt_long rmse mean: 1.8264535665512085
# dt_long rmse std: 0.3063837000752757
# dt_long average R^2 score: 0.5934449791908264
# dt_long R^2 score std: 0.2285827373234539
#
# param: (0, 5, 10, 100)
# dt_long rmse mean: 1.8188650846481322
# dt_long rmse std: 0.296637502520835
# dt_long average R^2 score: 0.6334957718849182
# dt_long R^2 score std: 0.1884138251388284
#
# param: (0, 5, 10, 200)
# dt_long rmse mean: 1.797845435142517
# dt_long rmse std: 0.3236958187565112
# dt_long average R^2 score: 0.633163571357727
# dt_long R^2 score std: 0.21071608315924928
#
# param: (0, 5, 15, 100)
# dt_long rmse mean: 1.783947467803955
# dt_long rmse std: 0.5104441909696159
# dt_long average R^2 score: 0.6522077679634094
# dt_long R^2 score std: 0.23141691852920449
#
# param: (0, 5, 15, 200)
# dt_long rmse mean: 1.7665894985198975
# dt_long rmse std: 0.4977978899893276
# dt_long average R^2 score: 0.6557013154029846
# dt_long R^2 score std: 0.23479506814573697
#
# param: (0, 5, 20, 100)
# dt_long rmse mean: 1.759060525894165
# dt_long rmse std: 0.6452396390343756
# dt_long average R^2 score: 0.6604600667953491
# dt_long R^2 score std: 0.2535394905007064
#
# param: (0, 5, 20, 200)
# dt_long rmse mean: 1.7526515483856202
# dt_long rmse std: 0.6350637887690713
# dt_long average R^2 score: 0.6615199089050293
# dt_long R^2 score std: 0.25360310064512437
#
# param: (0, 10, 5, 100)
# dt_long rmse mean: 1.7725111722946167
# dt_long rmse std: 0.28650583439901345
# dt_long average R^2 score: 0.6424056768417359
# dt_long R^2 score std: 0.1887137799795747
#
# param: (0, 10, 5, 200)
# dt_long rmse mean: 1.7451571464538573
# dt_long rmse std: 0.28846095608451283
# dt_long average R^2 score: 0.6371531248092651
# dt_long R^2 score std: 0.22336752033172647
#
# param: (0, 10, 10, 100)
# dt_long rmse mean: 1.8922290325164794
# dt_long rmse std: 0.4752009089869917
# dt_long average R^2 score: 0.6067393064498902
# dt_long R^2 score std: 0.22855888695151455
#
# param: (0, 10, 10, 200)
# dt_long rmse mean: 1.8451361656188965
# dt_long rmse std: 0.49997779661118896
# dt_long average R^2 score: 0.6171361207962036
# dt_long R^2 score std: 0.24289794363375605
#
# param: (0, 10, 15, 100)
# dt_long rmse mean: 1.6543282508850097
# dt_long rmse std: 0.4153435052567051
# dt_long average R^2 score: 0.703502094745636
# dt_long R^2 score std: 0.17461776213786395
#
# param: (0, 10, 15, 200)
# dt_long rmse mean: 1.6253280878067016
# dt_long rmse std: 0.4067909815925103
# dt_long average R^2 score: 0.709991729259491
# dt_long R^2 score std: 0.1788827835514754
#
# param: (0, 10, 20, 100)
# dt_long rmse mean: 1.597799587249756
# dt_long rmse std: 0.5304646092632476
# dt_long average R^2 score: 0.7248178243637085
# dt_long R^2 score std: 0.15457003182199797
#
# param: (0, 10, 20, 200)
# dt_long rmse mean: 1.5834304571151734
# dt_long rmse std: 0.5142961616958394
# dt_long average R^2 score: 0.726841390132904
# dt_long R^2 score std: 0.1565860768619273
#
# param: (0, 20, 5, 100)
# dt_long rmse mean: 1.7717826604843139
# dt_long rmse std: 0.22103923689502747
# dt_long average R^2 score: 0.6490352034568787
# dt_long R^2 score std: 0.1583949631862412
#
# param: (0, 20, 5, 200)
# dt_long rmse mean: 1.8142622470855714
# dt_long rmse std: 0.357208210441258
# dt_long average R^2 score: 0.6094637513160706
# dt_long R^2 score std: 0.22659754679905403
#
# param: (0, 20, 10, 100)
# dt_long rmse mean: 1.713836431503296
# dt_long rmse std: 0.332556776779698
# dt_long average R^2 score: 0.655830466747284
# dt_long R^2 score std: 0.2224922971096594
#
# param: (0, 20, 10, 200)
# dt_long rmse mean: 1.6490237712860107
# dt_long rmse std: 0.3418184088333425
# dt_long average R^2 score: 0.6712440013885498
# dt_long R^2 score std: 0.23313409438593005
#
# param: (0, 20, 15, 100)
# dt_long rmse mean: 1.667975115776062
# dt_long rmse std: 0.3587528168630359
# dt_long average R^2 score: 0.6744040489196778
# dt_long R^2 score std: 0.22167220398883572
#
# param: (0, 20, 15, 200)
# dt_long rmse mean: 1.6432624340057373
# dt_long rmse std: 0.36683161817320137
# dt_long average R^2 score: 0.6767871260643006
# dt_long R^2 score std: 0.23451755585827916
#
# param: (0, 20, 20, 100)
# dt_long rmse mean: 1.4817680239677429
# dt_long rmse std: 0.344043604049553
# dt_long average R^2 score: 0.7482365489006042
# dt_long R^2 score std: 0.14261822033227084
#
# param: (0, 20, 20, 200)
# dt_long rmse mean: 1.470533299446106
# dt_long rmse std: 0.3484728814818604
# dt_long average R^2 score: 0.750045096874237
# dt_long R^2 score std: 0.14460410820168437
#
# param: (1, 0, 5, 100)
# dt_long rmse mean: 1.7215575933456422
# dt_long rmse std: 0.21307455254387206
# dt_long average R^2 score: 0.6608654499053955
# dt_long R^2 score std: 0.16538503737824192
#
# param: (1, 0, 5, 200)
# dt_long rmse mean: 1.9000925302505494
# dt_long rmse std: 0.3375157962253377
# dt_long average R^2 score: 0.5556326150894165
# dt_long R^2 score std: 0.28955058616474183
#
# param: (1, 0, 10, 100)
# dt_long rmse mean: 2.0054665088653563
# dt_long rmse std: 0.5804365530141011
# dt_long average R^2 score: 0.4769960045814514
# dt_long R^2 score std: 0.48540555261913604
#
# param: (1, 0, 10, 200)
# dt_long rmse mean: 2.085566282272339
# dt_long rmse std: 0.6572131962576624
# dt_long average R^2 score: 0.4186999797821045
# dt_long R^2 score std: 0.5751516372564882
#
# param: (1, 0, 15, 100)
# dt_long rmse mean: 1.8514073610305786
# dt_long rmse std: 0.5319630032019421
# dt_long average R^2 score: 0.5351814150810241
# dt_long R^2 score std: 0.44258633858727353
#
# param: (1, 0, 15, 200)
# dt_long rmse mean: 1.8564981698989869
# dt_long rmse std: 0.5391562431702389
# dt_long average R^2 score: 0.5311782240867615
# dt_long R^2 score std: 0.44966591140117895
#
# param: (1, 0, 20, 100)
# dt_long rmse mean: 1.8088972091674804
# dt_long rmse std: 0.42197687944519063
# dt_long average R^2 score: 0.6087355852127075
# dt_long R^2 score std: 0.3003970515324324
#
# param: (1, 0, 20, 200)
# dt_long rmse mean: 1.8074145078659059
# dt_long rmse std: 0.4190429493419078
# dt_long average R^2 score: 0.6092000603675842
# dt_long R^2 score std: 0.2993054797596463
#
# param: (1, 1, 5, 100)
# dt_long rmse mean: 1.8334794521331788
# dt_long rmse std: 0.28084418981973863
# dt_long average R^2 score: 0.6376240968704223
# dt_long R^2 score std: 0.14401926500791024
#
# param: (1, 1, 5, 200)
# dt_long rmse mean: 1.9084034204483031
# dt_long rmse std: 0.32111091951674553
# dt_long average R^2 score: 0.5901604413986206
# dt_long R^2 score std: 0.23130335583370348
#
# param: (1, 1, 10, 100)
# dt_long rmse mean: 2.0202794551849363
# dt_long rmse std: 0.4664050177789423
# dt_long average R^2 score: 0.47575039863586427
# dt_long R^2 score std: 0.40841866709898705
#
# param: (1, 1, 10, 200)
# dt_long rmse mean: 2.018760561943054
# dt_long rmse std: 0.48995011002702515
# dt_long average R^2 score: 0.4673160076141357
# dt_long R^2 score std: 0.4270117612578574
#
# param: (1, 1, 15, 100)
# dt_long rmse mean: 1.702715802192688
# dt_long rmse std: 0.38021674397411526
# dt_long average R^2 score: 0.6568466544151306
# dt_long R^2 score std: 0.2528058638822608
#
# param: (1, 1, 15, 200)
# dt_long rmse mean: 1.7011438608169556
# dt_long rmse std: 0.37788462073549073
# dt_long average R^2 score: 0.6569772481918335
# dt_long R^2 score std: 0.2529492636578782
#
# param: (1, 1, 20, 100)
# dt_long rmse mean: 1.7541853427886962
# dt_long rmse std: 0.469328287391124
# dt_long average R^2 score: 0.6674491405487061
# dt_long R^2 score std: 0.2018478392024496
#
# param: (1, 1, 20, 200)
# dt_long rmse mean: 1.7493106365203857
# dt_long rmse std: 0.4691180389191135
# dt_long average R^2 score: 0.6688501000404358
# dt_long R^2 score std: 0.2022050869150211
#
# param: (1, 3, 5, 100)
# dt_long rmse mean: 1.7584761142730714
# dt_long rmse std: 0.14985381662633684
# dt_long average R^2 score: 0.6484812140464783
# dt_long R^2 score std: 0.15671008577861048
#
# param: (1, 3, 5, 200)
# dt_long rmse mean: 1.920146369934082
# dt_long rmse std: 0.34363196901397286
# dt_long average R^2 score: 0.5406475782394409
# dt_long R^2 score std: 0.2978569656074078
#
# param: (1, 3, 10, 100)
# dt_long rmse mean: 1.7025216341018676
# dt_long rmse std: 0.39314509311841844
# dt_long average R^2 score: 0.6417533755302429
# dt_long R^2 score std: 0.28213800955518376
#
# param: (1, 3, 10, 200)
# dt_long rmse mean: 1.6931496143341065
# dt_long rmse std: 0.4471234201867243
# dt_long average R^2 score: 0.6304856538772583
# dt_long R^2 score std: 0.3158375767992916
#
# param: (1, 3, 15, 100)
# dt_long rmse mean: 1.79442138671875
# dt_long rmse std: 0.5825404792035028
# dt_long average R^2 score: 0.6212279200553894
# dt_long R^2 score std: 0.3066974129320443
#
# param: (1, 3, 15, 200)
# dt_long rmse mean: 1.787847113609314
# dt_long rmse std: 0.5714817267465535
# dt_long average R^2 score: 0.6252918601036072
# dt_long R^2 score std: 0.2999427607346932
#
# param: (1, 3, 20, 100)
# dt_long rmse mean: 1.6721760034561157
# dt_long rmse std: 0.422106176821727
# dt_long average R^2 score: 0.6825317144393921
# dt_long R^2 score std: 0.19836532796425788
#
# param: (1, 3, 20, 200)
# dt_long rmse mean: 1.6584014534950255
# dt_long rmse std: 0.41792408208849485
# dt_long average R^2 score: 0.686295461654663
# dt_long R^2 score std: 0.19898811874126401
#
# param: (1, 5, 5, 100)
# dt_long rmse mean: 1.768006443977356
# dt_long rmse std: 0.2848271820353308
# dt_long average R^2 score: 0.656582260131836
# dt_long R^2 score std: 0.16155759346296245
#
# param: (1, 5, 5, 200)
# dt_long rmse mean: 1.7400673866271972
# dt_long rmse std: 0.2603292412207342
# dt_long average R^2 score: 0.6440200567245483
# dt_long R^2 score std: 0.19908984346035064
#
# param: (1, 5, 10, 100)
# dt_long rmse mean: 1.8413497686386109
# dt_long rmse std: 0.3371224289387999
# dt_long average R^2 score: 0.6029799818992615
# dt_long R^2 score std: 0.2444750507821104
#
# param: (1, 5, 10, 200)
# dt_long rmse mean: 1.8288141012191772
# dt_long rmse std: 0.34289120780269916
# dt_long average R^2 score: 0.6053151845932007
# dt_long R^2 score std: 0.24794871818321268
#
# param: (1, 5, 15, 100)
# dt_long rmse mean: 1.685312569141388
# dt_long rmse std: 0.6124802911180798
# dt_long average R^2 score: 0.6795281291007995
# dt_long R^2 score std: 0.2416562850008949
#
# param: (1, 5, 15, 200)
# dt_long rmse mean: 1.6785606145858765
# dt_long rmse std: 0.5946517265757884
# dt_long average R^2 score: 0.6775385618209839
# dt_long R^2 score std: 0.2488737834827124
#
# param: (1, 5, 20, 100)
# dt_long rmse mean: 1.7218825817108154
# dt_long rmse std: 0.5781371057563099
# dt_long average R^2 score: 0.6813965916633606
# dt_long R^2 score std: 0.1951119262448496
#
# param: (1, 5, 20, 200)
# dt_long rmse mean: 1.7173778057098388
# dt_long rmse std: 0.5575482540427774
# dt_long average R^2 score: 0.6842641472816468
# dt_long R^2 score std: 0.18870913304832837
#
# param: (1, 10, 5, 100)
# dt_long rmse mean: 1.8205258131027222
# dt_long rmse std: 0.2933498073677915
# dt_long average R^2 score: 0.6323204755783081
# dt_long R^2 score std: 0.1746591004167815
#
# param: (1, 10, 5, 200)
# dt_long rmse mean: 1.8008349418640137
# dt_long rmse std: 0.36033806703657095
# dt_long average R^2 score: 0.6147074341773987
# dt_long R^2 score std: 0.2286394476067356
#
# param: (1, 10, 10, 100)
# dt_long rmse mean: 1.7162455320358276
# dt_long rmse std: 0.31056926576742083
# dt_long average R^2 score: 0.6506081938743591
# dt_long R^2 score std: 0.22071762454636687
#
# param: (1, 10, 10, 200)
# dt_long rmse mean: 1.672497034072876
# dt_long rmse std: 0.3641379426199065
# dt_long average R^2 score: 0.6541052460670471
# dt_long R^2 score std: 0.2474670113509721
#
# param: (1, 10, 15, 100)
# dt_long rmse mean: 1.652248239517212
# dt_long rmse std: 0.40160056984591397
# dt_long average R^2 score: 0.6854594588279724
# dt_long R^2 score std: 0.20103881809359334
#
# param: (1, 10, 15, 200)
# dt_long rmse mean: 1.6262242317199707
# dt_long rmse std: 0.4126430933134295
# dt_long average R^2 score: 0.6897620320320129
# dt_long R^2 score std: 0.21236324101538856
#
# param: (1, 10, 20, 100)
# dt_long rmse mean: 1.5881296157836915
# dt_long rmse std: 0.5675615157709111
# dt_long average R^2 score: 0.7322062373161315
# dt_long R^2 score std: 0.14612165175215497
#
# param: (1, 10, 20, 200)
# dt_long rmse mean: 1.572004497051239
# dt_long rmse std: 0.5582608272861058
# dt_long average R^2 score: 0.7331173181533813
# dt_long R^2 score std: 0.15520488041010716
#
# param: (1, 20, 5, 100)
# dt_long rmse mean: 1.7536365509033203
# dt_long rmse std: 0.2169314259819898
# dt_long average R^2 score: 0.6545456886291504
# dt_long R^2 score std: 0.15814629733779223
#
# param: (1, 20, 5, 200)
# dt_long rmse mean: 1.7697543382644654
# dt_long rmse std: 0.24361091597274506
# dt_long average R^2 score: 0.6335150957107544
# dt_long R^2 score std: 0.1889305117578351
#
# param: (1, 20, 10, 100)
# dt_long rmse mean: 1.793901801109314
# dt_long rmse std: 0.27420604868996584
# dt_long average R^2 score: 0.6148922443389893
# dt_long R^2 score std: 0.22433188050411335
#
# param: (1, 20, 10, 200)
# dt_long rmse mean: 1.7132213830947876
# dt_long rmse std: 0.2958262859139276
# dt_long average R^2 score: 0.6379163980484008
# dt_long R^2 score std: 0.22292997166246728
#
# param: (1, 20, 15, 100)
# dt_long rmse mean: 1.6856819629669189
# dt_long rmse std: 0.3294722311531145
# dt_long average R^2 score: 0.6701522469520569
# dt_long R^2 score std: 0.20897466274311147
#
# param: (1, 20, 15, 200)
# dt_long rmse mean: 1.6251384973526002
# dt_long rmse std: 0.3425379165591431
# dt_long average R^2 score: 0.6853183150291443
# dt_long R^2 score std: 0.21672826902594067
#
# param: (1, 20, 20, 100)
# dt_long rmse mean: 1.5089077830314637
# dt_long rmse std: 0.34979489961691257
# dt_long average R^2 score: 0.7440327763557434
# dt_long R^2 score std: 0.13319537108421406
#
# param: (1, 20, 20, 200)
# dt_long rmse mean: 1.4901681423187256
# dt_long rmse std: 0.3575649074639859
# dt_long average R^2 score: 0.7484533190727234
# dt_long R^2 score std: 0.13546609494128858
#
# param: (3, 0, 5, 100)
# dt_long rmse mean: 1.731361198425293
# dt_long rmse std: 0.2230200287681035
# dt_long average R^2 score: 0.6515456318855286
# dt_long R^2 score std: 0.17467062121094135
#
# param: (3, 0, 5, 200)
# dt_long rmse mean: 1.882274055480957
# dt_long rmse std: 0.35651728440639074
# dt_long average R^2 score: 0.5578774452209473
# dt_long R^2 score std: 0.3089335854898507
#
# param: (3, 0, 10, 100)
# dt_long rmse mean: 1.8499595880508424
# dt_long rmse std: 0.4397094715280998
# dt_long average R^2 score: 0.5542306065559387
# dt_long R^2 score std: 0.3529290373723735
#
# param: (3, 0, 10, 200)
# dt_long rmse mean: 1.8740506887435913
# dt_long rmse std: 0.5062910630312598
# dt_long average R^2 score: 0.5307752013206481
# dt_long R^2 score std: 0.3938516786644378
#
# param: (3, 0, 15, 100)
# dt_long rmse mean: 1.9138756275177002
# dt_long rmse std: 0.39006040720242885
# dt_long average R^2 score: 0.5651832222938538
# dt_long R^2 score std: 0.29880400038996
#
# param: (3, 0, 15, 200)
# dt_long rmse mean: 1.8919946670532226
# dt_long rmse std: 0.4022913802201968
# dt_long average R^2 score: 0.5731594324111938
# dt_long R^2 score std: 0.30093326486689803
#
# param: (3, 0, 20, 100)
# dt_long rmse mean: 1.6924829006195068
# dt_long rmse std: 0.5039682809461088
# dt_long average R^2 score: 0.6957293629646302
# dt_long R^2 score std: 0.15708347265523898
#
# param: (3, 0, 20, 200)
# dt_long rmse mean: 1.672870111465454
# dt_long rmse std: 0.4873408707220668
# dt_long average R^2 score: 0.6989260911941528
# dt_long R^2 score std: 0.1613049635864991
#
# param: (3, 1, 5, 100)
# dt_long rmse mean: 1.7944345712661742
# dt_long rmse std: 0.3056727952672485
# dt_long average R^2 score: 0.6435077667236329
# dt_long R^2 score std: 0.1717493879852421
#
# param: (3, 1, 5, 200)
# dt_long rmse mean: 1.8835224390029908
# dt_long rmse std: 0.3441570580026708
# dt_long average R^2 score: 0.5778993964195251
# dt_long R^2 score std: 0.2832667173142654
#
# param: (3, 1, 10, 100)
# dt_long rmse mean: 1.9082993984222412
# dt_long rmse std: 0.5751457052589871
# dt_long average R^2 score: 0.49737809896469115
# dt_long R^2 score std: 0.4866482432169649
#
# param: (3, 1, 10, 200)
# dt_long rmse mean: 1.9338631629943848
# dt_long rmse std: 0.6123464841416721
# dt_long average R^2 score: 0.4723763346672058
# dt_long R^2 score std: 0.5144453073444692
#
# param: (3, 1, 15, 100)
# dt_long rmse mean: 1.7730884313583375
# dt_long rmse std: 0.29148905786369456
# dt_long average R^2 score: 0.6470141887664795
# dt_long R^2 score std: 0.19653584634101023
#
# param: (3, 1, 15, 200)
# dt_long rmse mean: 1.7472361326217651
# dt_long rmse std: 0.2902166040960633
# dt_long average R^2 score: 0.6557185530662537
# dt_long R^2 score std: 0.19534421643501812
#
# param: (3, 1, 20, 100)
# dt_long rmse mean: 1.5858085393905639
# dt_long rmse std: 0.4711954217434154
# dt_long average R^2 score: 0.7266209483146667
# dt_long R^2 score std: 0.1479888305975888
#
# param: (3, 1, 20, 200)
# dt_long rmse mean: 1.584873914718628
# dt_long rmse std: 0.46944431873925074
# dt_long average R^2 score: 0.726858913898468
# dt_long R^2 score std: 0.148335240169208
#
# param: (3, 3, 5, 100)
# dt_long rmse mean: 1.7340902090072632
# dt_long rmse std: 0.22995234542795795
# dt_long average R^2 score: 0.6570490717887878
# dt_long R^2 score std: 0.17228058182369466
#
# param: (3, 3, 5, 200)
# dt_long rmse mean: 1.8659248113632203
# dt_long rmse std: 0.2571399137888197
# dt_long average R^2 score: 0.5970507025718689
# dt_long R^2 score std: 0.2271935053981099
#
# param: (3, 3, 10, 100)
# dt_long rmse mean: 1.7317297458648682
# dt_long rmse std: 0.2515924418223709
# dt_long average R^2 score: 0.6395952343940735
# dt_long R^2 score std: 0.21854187164929992
#
# param: (3, 3, 10, 200)
# dt_long rmse mean: 1.8184622287750245
# dt_long rmse std: 0.26495329904930204
# dt_long average R^2 score: 0.5999982237815857
# dt_long R^2 score std: 0.2408934742169433
#
# param: (3, 3, 15, 100)
# dt_long rmse mean: 1.7710055828094482
# dt_long rmse std: 0.5267650138572763
# dt_long average R^2 score: 0.6569815516471863
# dt_long R^2 score std: 0.22684571629469144
#
# param: (3, 3, 15, 200)
# dt_long rmse mean: 1.760300087928772
# dt_long rmse std: 0.5244685776731287
# dt_long average R^2 score: 0.6555957674980164
# dt_long R^2 score std: 0.24116835766435168
#
# param: (3, 3, 20, 100)
# dt_long rmse mean: 1.5304959535598754
# dt_long rmse std: 0.5007146698000207
# dt_long average R^2 score: 0.7435726284980774
# dt_long R^2 score std: 0.15257367890731335
#
# param: (3, 3, 20, 200)
# dt_long rmse mean: 1.5196360230445862
# dt_long rmse std: 0.5059661048513793
# dt_long average R^2 score: 0.7474993705749512
# dt_long R^2 score std: 0.15134221331524694
#
# param: (3, 5, 5, 100)
# dt_long rmse mean: 1.82494113445282
# dt_long rmse std: 0.2697381409225804
# dt_long average R^2 score: 0.6344631433486938
# dt_long R^2 score std: 0.15791436923106564
#
# param: (3, 5, 5, 200)
# dt_long rmse mean: 1.8030655145645142
# dt_long rmse std: 0.22290659813635186
# dt_long average R^2 score: 0.6415842056274415
# dt_long R^2 score std: 0.1591805759139403
#
# param: (3, 5, 10, 100)
# dt_long rmse mean: 1.8018035411834716
# dt_long rmse std: 0.3173719186275876
# dt_long average R^2 score: 0.5927854061126709
# dt_long R^2 score std: 0.270128516134232
#
# param: (3, 5, 10, 200)
# dt_long rmse mean: 1.7825999975204467
# dt_long rmse std: 0.3787050755693858
# dt_long average R^2 score: 0.5876646757125854
# dt_long R^2 score std: 0.2896875839598962
#
# param: (3, 5, 15, 100)
# dt_long rmse mean: 1.6691513776779174
# dt_long rmse std: 0.49566585371414146
# dt_long average R^2 score: 0.6959715604782104
# dt_long R^2 score std: 0.17906357789600136
#
# param: (3, 5, 15, 200)
# dt_long rmse mean: 1.6326029658317567
# dt_long rmse std: 0.46403966267160535
# dt_long average R^2 score: 0.705274784564972
# dt_long R^2 score std: 0.17743677790343299
#
# param: (3, 5, 20, 100)
# dt_long rmse mean: 1.5246797800064087
# dt_long rmse std: 0.5596846049265392
# dt_long average R^2 score: 0.7544033169746399
# dt_long R^2 score std: 0.12972572212380556
#
# param: (3, 5, 20, 200)
# dt_long rmse mean: 1.5118279933929444
# dt_long rmse std: 0.5680201255450801
# dt_long average R^2 score: 0.7575775027275086
# dt_long R^2 score std: 0.13178241863455226
#
# param: (3, 10, 5, 100)
# dt_long rmse mean: 1.798994278907776
# dt_long rmse std: 0.2672941216822456
# dt_long average R^2 score: 0.6357251167297363
# dt_long R^2 score std: 0.18107940991465285
#
# param: (3, 10, 5, 200)
# dt_long rmse mean: 1.8119517803192138
# dt_long rmse std: 0.3758146011867092
# dt_long average R^2 score: 0.6133462071418763
# dt_long R^2 score std: 0.23092412764933495
#
# param: (3, 10, 10, 100)
# dt_long rmse mean: 1.6757060766220093
# dt_long rmse std: 0.25731973145636755
# dt_long average R^2 score: 0.6568465828895569
# dt_long R^2 score std: 0.21816815690668553
#
# param: (3, 10, 10, 200)
# dt_long rmse mean: 1.6228325366973877
# dt_long rmse std: 0.2932594370963908
# dt_long average R^2 score: 0.6685278177261352
# dt_long R^2 score std: 0.22600161192752452
#
# param: (3, 10, 15, 100)
# dt_long rmse mean: 1.7067250728607177
# dt_long rmse std: 0.5434457630073499
# dt_long average R^2 score: 0.6771459817886353
# dt_long R^2 score std: 0.21660731791120452
#
# param: (3, 10, 15, 200)
# dt_long rmse mean: 1.6711117029190063
# dt_long rmse std: 0.5394495253409056
# dt_long average R^2 score: 0.6813316941261292
# dt_long R^2 score std: 0.23155715847519415
#
# param: (3, 10, 20, 100)
# dt_long rmse mean: 1.4457326769828795
# dt_long rmse std: 0.41210342234692
# dt_long average R^2 score: 0.7752063155174256
# dt_long R^2 score std: 0.11836923914858384
#
# param: (3, 10, 20, 200)
# dt_long rmse mean: 1.4481636881828308
# dt_long rmse std: 0.407553584886631
# dt_long average R^2 score: 0.7692428588867187
# dt_long R^2 score std: 0.12987725125420546
#
# param: (3, 20, 5, 100)
# dt_long rmse mean: 1.7930908203125
# dt_long rmse std: 0.24971972808785234
# dt_long average R^2 score: 0.6477872371673584
# dt_long R^2 score std: 0.15390533502705195
#
# param: (3, 20, 5, 200)
# dt_long rmse mean: 1.7595687627792358
# dt_long rmse std: 0.26144279971527573
# dt_long average R^2 score: 0.6531647205352783
# dt_long R^2 score std: 0.1706059970812117
#
# param: (3, 20, 10, 100)
# dt_long rmse mean: 1.8014753580093383
# dt_long rmse std: 0.23856997182263714
# dt_long average R^2 score: 0.6180322289466857
# dt_long R^2 score std: 0.21127596372522717
#
# param: (3, 20, 10, 200)
# dt_long rmse mean: 1.706309700012207
# dt_long rmse std: 0.265288839504842
# dt_long average R^2 score: 0.6476106166839599
# dt_long R^2 score std: 0.20953231638062692
#
# param: (3, 20, 15, 100)
# dt_long rmse mean: 1.6339539766311646
# dt_long rmse std: 0.40270195905169215
# dt_long average R^2 score: 0.6787960290908813
# dt_long R^2 score std: 0.24263306804988855
#
# param: (3, 20, 15, 200)
# dt_long rmse mean: 1.6090735912322998
# dt_long rmse std: 0.42554931805455953
# dt_long average R^2 score: 0.6779194593429565
# dt_long R^2 score std: 0.26345821200508873
#
# param: (3, 20, 20, 100)
# dt_long rmse mean: 1.5556781053543092
# dt_long rmse std: 0.3436091470348855
# dt_long average R^2 score: 0.7201285481452941
# dt_long R^2 score std: 0.16958606070130827
#
# param: (3, 20, 20, 200)
# dt_long rmse mean: 1.5413333654403687
# dt_long rmse std: 0.3628365521681266
# dt_long average R^2 score: 0.7178217768669128
# dt_long R^2 score std: 0.1846883031679124
#
# param: (5, 0, 5, 100)
# dt_long rmse mean: 1.7963637351989745
# dt_long rmse std: 0.2305923075517408
# dt_long average R^2 score: 0.6340500712394714
# dt_long R^2 score std: 0.17404319873583404
#
# param: (5, 0, 5, 200)
# dt_long rmse mean: 1.9469345331192016
# dt_long rmse std: 0.4665334063996391
# dt_long average R^2 score: 0.5381307959556579
# dt_long R^2 score std: 0.3698958034531063
#
# param: (5, 0, 10, 100)
# dt_long rmse mean: 1.8366832971572875
# dt_long rmse std: 0.5202819812865733
# dt_long average R^2 score: 0.531399154663086
# dt_long R^2 score std: 0.4342581515506272
#
# param: (5, 0, 10, 200)
# dt_long rmse mean: 1.8816212654113769
# dt_long rmse std: 0.6155891933559227
# dt_long average R^2 score: 0.4853360652923584
# dt_long R^2 score std: 0.5267795139578281
#
# param: (5, 0, 15, 100)
# dt_long rmse mean: 1.7970654726028443
# dt_long rmse std: 0.5152529156318688
# dt_long average R^2 score: 0.6393836855888366
# dt_long R^2 score std: 0.2362442404750896
#
# param: (5, 0, 15, 200)
# dt_long rmse mean: 1.7959378004074096
# dt_long rmse std: 0.5146594233001616
# dt_long average R^2 score: 0.6333383679389953
# dt_long R^2 score std: 0.25741393505231935
#
# param: (5, 0, 20, 100)
# dt_long rmse mean: 1.7108021974563599
# dt_long rmse std: 0.5933946609320733
# dt_long average R^2 score: 0.7028385400772095
# dt_long R^2 score std: 0.1279194211295799
#
# param: (5, 0, 20, 200)
# dt_long rmse mean: 1.699039363861084
# dt_long rmse std: 0.5687486544214896
# dt_long average R^2 score: 0.7050238251686096
# dt_long R^2 score std: 0.12801176686066176
#
# param: (5, 1, 5, 100)
# dt_long rmse mean: 1.8351269483566284
# dt_long rmse std: 0.25259048790928795
# dt_long average R^2 score: 0.6337436199188232
# dt_long R^2 score std: 0.14929319406903988
#
# param: (5, 1, 5, 200)
# dt_long rmse mean: 1.7473097085952758
# dt_long rmse std: 0.2110256236362352
# dt_long average R^2 score: 0.6504700541496277
# dt_long R^2 score std: 0.18428509620970793
#
# param: (5, 1, 10, 100)
# dt_long rmse mean: 1.735059952735901
# dt_long rmse std: 0.2518306288007234
# dt_long average R^2 score: 0.644822633266449
# dt_long R^2 score std: 0.2159730735779454
#
# param: (5, 1, 10, 200)
# dt_long rmse mean: 1.7499295949935914
# dt_long rmse std: 0.346586731234665
# dt_long average R^2 score: 0.6157670378684997
# dt_long R^2 score std: 0.2856813647663183
#
# param: (5, 1, 15, 100)
# dt_long rmse mean: 1.8226559162139893
# dt_long rmse std: 0.42261713226980197
# dt_long average R^2 score: 0.6506636142730713
# dt_long R^2 score std: 0.1520987193751819
#
# param: (5, 1, 15, 200)
# dt_long rmse mean: 1.799338412284851
# dt_long rmse std: 0.41388354304980257
# dt_long average R^2 score: 0.6586360812187195
# dt_long R^2 score std: 0.153223374910633
#
# param: (5, 1, 20, 100)
# dt_long rmse mean: 1.597837996482849
# dt_long rmse std: 0.4954114685245344
# dt_long average R^2 score: 0.7331325650215149
# dt_long R^2 score std: 0.13008067381914892
#
# param: (5, 1, 20, 200)
# dt_long rmse mean: 1.5934065580368042
# dt_long rmse std: 0.4851352946174482
# dt_long average R^2 score: 0.7347278356552124
# dt_long R^2 score std: 0.12808154912250547
#
# param: (5, 3, 5, 100)
# dt_long rmse mean: 1.8304794073104858
# dt_long rmse std: 0.3069750748687353
# dt_long average R^2 score: 0.6084821105003357
# dt_long R^2 score std: 0.2297965918174731
#
# param: (5, 3, 5, 200)
# dt_long rmse mean: 1.8508081197738648
# dt_long rmse std: 0.42571152063157786
# dt_long average R^2 score: 0.5690375804901123
# dt_long R^2 score std: 0.3502872055239912
#
# param: (5, 3, 10, 100)
# dt_long rmse mean: 1.8364710569381715
# dt_long rmse std: 0.2812761997035152
# dt_long average R^2 score: 0.614713728427887
# dt_long R^2 score std: 0.21451412948954712
#
# param: (5, 3, 10, 200)
# dt_long rmse mean: 1.8142923831939697
# dt_long rmse std: 0.32651895797314
# dt_long average R^2 score: 0.6125422954559326
# dt_long R^2 score std: 0.24058330260107894
#
# param: (5, 3, 15, 100)
# dt_long rmse mean: 1.697768759727478
# dt_long rmse std: 0.4569716229572076
# dt_long average R^2 score: 0.7076821208000184
# dt_long R^2 score std: 0.11796763672384705
#
# param: (5, 3, 15, 200)
# dt_long rmse mean: 1.6717293500900268
# dt_long rmse std: 0.45834061531380726
# dt_long average R^2 score: 0.7152871012687683
# dt_long R^2 score std: 0.12036679036438744
#
# param: (5, 3, 20, 100)
# dt_long rmse mean: 1.5235770702362061
# dt_long rmse std: 0.46706876387336627
# dt_long average R^2 score: 0.7596619963645935
# dt_long R^2 score std: 0.11318657917125473
#
# param: (5, 3, 20, 200)
# dt_long rmse mean: 1.5009100198745728
# dt_long rmse std: 0.45165226518092755
# dt_long average R^2 score: 0.7654565095901489
# dt_long R^2 score std: 0.11220665861794975
#
# param: (5, 5, 5, 100)
# dt_long rmse mean: 1.7855457305908202
# dt_long rmse std: 0.22630329444753267
# dt_long average R^2 score: 0.6323540329933166
# dt_long R^2 score std: 0.1805270673002828
#
# param: (5, 5, 5, 200)
# dt_long rmse mean: 1.7458931446075439
# dt_long rmse std: 0.16675970702888224
# dt_long average R^2 score: 0.6410688757896423
# dt_long R^2 score std: 0.18854773793925905
#
# param: (5, 5, 10, 100)
# dt_long rmse mean: 1.8013278722763062
# dt_long rmse std: 0.4535549471429289
# dt_long average R^2 score: 0.5782330632209778
# dt_long R^2 score std: 0.3395556609078389
#
# param: (5, 5, 10, 200)
# dt_long rmse mean: 1.7615699291229248
# dt_long rmse std: 0.48828731339248405
# dt_long average R^2 score: 0.5838610410690308
# dt_long R^2 score std: 0.3371824720836366
#
# param: (5, 5, 15, 100)
# dt_long rmse mean: 1.5968930006027222
# dt_long rmse std: 0.43588053405393234
# dt_long average R^2 score: 0.7163046360015869
# dt_long R^2 score std: 0.1710226192662725
#
# param: (5, 5, 15, 200)
# dt_long rmse mean: 1.5755465984344483
# dt_long rmse std: 0.45955071032387546
# dt_long average R^2 score: 0.7199740648269654
# dt_long R^2 score std: 0.18228855844707023
#
# param: (5, 5, 20, 100)
# dt_long rmse mean: 1.4723360896110536
# dt_long rmse std: 0.4982395568837572
# dt_long average R^2 score: 0.7727552652359009
# dt_long R^2 score std: 0.10449481040500241
#
# param: (5, 5, 20, 200)
# dt_long rmse mean: 1.4659259557723998
# dt_long rmse std: 0.4930394010698242
# dt_long average R^2 score: 0.774292266368866
# dt_long R^2 score std: 0.10514262120232463
#
# param: (5, 10, 5, 100)
# dt_long rmse mean: 1.7689477920532226
# dt_long rmse std: 0.2681678906374583
# dt_long average R^2 score: 0.6518547654151916
# dt_long R^2 score std: 0.1677027025255105
#
# param: (5, 10, 5, 200)
# dt_long rmse mean: 1.7523755311965943
# dt_long rmse std: 0.263359675385736
# dt_long average R^2 score: 0.6441891193389893
# dt_long R^2 score std: 0.18986227854155768
#
# param: (5, 10, 10, 100)
# dt_long rmse mean: 1.6694441318511963
# dt_long rmse std: 0.215635015451899
# dt_long average R^2 score: 0.674040925502777
# dt_long R^2 score std: 0.18434240949936062
#
# param: (5, 10, 10, 200)
# dt_long rmse mean: 1.5907108783721924
# dt_long rmse std: 0.22896463461315203
# dt_long average R^2 score: 0.6978748798370361
# dt_long R^2 score std: 0.18453557259851522
#
# param: (5, 10, 15, 100)
# dt_long rmse mean: 1.658120036125183
# dt_long rmse std: 0.47220311245209295
# dt_long average R^2 score: 0.6813462853431702
# dt_long R^2 score std: 0.2361755511464522
#
# param: (5, 10, 15, 200)
# dt_long rmse mean: 1.6327671527862548
# dt_long rmse std: 0.4967110673792164
# dt_long average R^2 score: 0.6884512662887573
# dt_long R^2 score std: 0.2419942707849316
#
# param: (5, 10, 20, 100)
# dt_long rmse mean: 1.4712731838226318
# dt_long rmse std: 0.30223642633062325
# dt_long average R^2 score: 0.7600543856620788
# dt_long R^2 score std: 0.12517945694724603
#
# param: (5, 10, 20, 200)
# dt_long rmse mean: 1.4656667709350586
# dt_long rmse std: 0.31007338035401455
# dt_long average R^2 score: 0.7571258544921875
# dt_long R^2 score std: 0.13708224120187576
#
# param: (5, 20, 5, 100)
# dt_long rmse mean: 1.7586607694625855
# dt_long rmse std: 0.22660371480847713
# dt_long average R^2 score: 0.6510838270187378
# dt_long R^2 score std: 0.16291252092167913
#
# param: (5, 20, 5, 200)
# dt_long rmse mean: 1.7436800718307495
# dt_long rmse std: 0.27698320903873364
# dt_long average R^2 score: 0.6491499066352844
# dt_long R^2 score std: 0.19163004435012795
#
# param: (5, 20, 10, 100)
# dt_long rmse mean: 1.7736474990844726
# dt_long rmse std: 0.2569685584061814
# dt_long average R^2 score: 0.6431447625160217
# dt_long R^2 score std: 0.1875273290452084
#
# param: (5, 20, 10, 200)
# dt_long rmse mean: 1.7050575256347655
# dt_long rmse std: 0.2823728493171111
# dt_long average R^2 score: 0.6682667016983033
# dt_long R^2 score std: 0.18712719747025724
#
# param: (5, 20, 15, 100)
# dt_long rmse mean: 1.6080803632736207
# dt_long rmse std: 0.35586088230448
# dt_long average R^2 score: 0.6855693340301514
# dt_long R^2 score std: 0.232550299873966
#
# param: (5, 20, 15, 200)
# dt_long rmse mean: 1.5674927711486817
# dt_long rmse std: 0.37375139479914166
# dt_long average R^2 score: 0.6934102892875671
# dt_long R^2 score std: 0.24217168889594315
#
# param: (5, 20, 20, 100)
# dt_long rmse mean: 1.4728533029556274
# dt_long rmse std: 0.30540310472916105
# dt_long average R^2 score: 0.7496025919914245
# dt_long R^2 score std: 0.13966713513532686
#
# param: (5, 20, 20, 200)
# dt_long rmse mean: 1.4501082062721253
# dt_long rmse std: 0.3052650211526815
# dt_long average R^2 score: 0.7516872882843018
# dt_long R^2 score std: 0.14618336487908573
#
# param: (10, 0, 5, 100)
# dt_long rmse mean: 1.8357744932174682
# dt_long rmse std: 0.26830793126724417
# dt_long average R^2 score: 0.6196617484092712
# dt_long R^2 score std: 0.18866482958228092
#
# param: (10, 0, 5, 200)
# dt_long rmse mean: 1.9297886610031127
# dt_long rmse std: 0.3459169532765289
# dt_long average R^2 score: 0.5564757943153381
# dt_long R^2 score std: 0.28960424965102616
#
# param: (10, 0, 10, 100)
# dt_long rmse mean: 1.884432029724121
# dt_long rmse std: 0.3698451033358429
# dt_long average R^2 score: 0.5617445230484008
# dt_long R^2 score std: 0.32326729332479553
#
# param: (10, 0, 10, 200)
# dt_long rmse mean: 1.961770510673523
# dt_long rmse std: 0.46223485802670083
# dt_long average R^2 score: 0.5087818741798401
# dt_long R^2 score std: 0.3977732457427726
#
# param: (10, 0, 15, 100)
# dt_long rmse mean: 1.8312997817993164
# dt_long rmse std: 0.4281519383525915
# dt_long average R^2 score: 0.6415851831436157
# dt_long R^2 score std: 0.17053366333657213
#
# param: (10, 0, 15, 200)
# dt_long rmse mean: 1.811907172203064
# dt_long rmse std: 0.4245999235102513
# dt_long average R^2 score: 0.6509238243103027
# dt_long R^2 score std: 0.1627549248626131
#
# param: (10, 0, 20, 100)
# dt_long rmse mean: 1.5366107940673828
# dt_long rmse std: 0.49281070394909776
# dt_long average R^2 score: 0.7524160742759705
# dt_long R^2 score std: 0.1135267200364668
#
# param: (10, 0, 20, 200)
# dt_long rmse mean: 1.5301353454589843
# dt_long rmse std: 0.4770204328436181
# dt_long average R^2 score: 0.7535620927810669
# dt_long R^2 score std: 0.11209842642829355
#
# param: (10, 1, 5, 100)
# dt_long rmse mean: 1.7632453203201295
# dt_long rmse std: 0.22123986028189627
# dt_long average R^2 score: 0.6497813105583191
# dt_long R^2 score std: 0.1649655759741061
#
# param: (10, 1, 5, 200)
# dt_long rmse mean: 1.8625986337661744
# dt_long rmse std: 0.5261457099985076
# dt_long average R^2 score: 0.54762864112854
# dt_long R^2 score std: 0.4229401365350241
#
# param: (10, 1, 10, 100)
# dt_long rmse mean: 1.926109218597412
# dt_long rmse std: 0.34560429724956016
# dt_long average R^2 score: 0.5602485656738281
# dt_long R^2 score std: 0.2946871210355623
#
# param: (10, 1, 10, 200)
# dt_long rmse mean: 1.976633620262146
# dt_long rmse std: 0.42258149686408697
# dt_long average R^2 score: 0.5276125907897949
# dt_long R^2 score std: 0.3553999875521493
#
# param: (10, 1, 15, 100)
# dt_long rmse mean: 1.7192317485809325
# dt_long rmse std: 0.46060729059280436
# dt_long average R^2 score: 0.6863819837570191
# dt_long R^2 score std: 0.16258310261911676
#
# param: (10, 1, 15, 200)
# dt_long rmse mean: 1.6867900848388673
# dt_long rmse std: 0.4935631348194753
# dt_long average R^2 score: 0.6951777935028076
# dt_long R^2 score std: 0.1740118637749965
#
# param: (10, 1, 20, 100)
# dt_long rmse mean: 1.595579195022583
# dt_long rmse std: 0.4076801866844965
# dt_long average R^2 score: 0.7293590545654297
# dt_long R^2 score std: 0.11721345973245484
#
# param: (10, 1, 20, 200)
# dt_long rmse mean: 1.5881038188934327
# dt_long rmse std: 0.4142424154105598
# dt_long average R^2 score: 0.7322097778320312
# dt_long R^2 score std: 0.11740563784055787
#
# param: (10, 3, 5, 100)
# dt_long rmse mean: 1.783012080192566
# dt_long rmse std: 0.2411432069998359
# dt_long average R^2 score: 0.643718147277832
# dt_long R^2 score std: 0.16856276285013025
#
# param: (10, 3, 5, 200)
# dt_long rmse mean: 1.8407825708389283
# dt_long rmse std: 0.3079454741027476
# dt_long average R^2 score: 0.6102992177009583
# dt_long R^2 score std: 0.2373896935771941
#
# param: (10, 3, 10, 100)
# dt_long rmse mean: 1.9054130554199218
# dt_long rmse std: 0.36416086120068186
# dt_long average R^2 score: 0.5569571852684021
# dt_long R^2 score std: 0.3087653617606627
#
# param: (10, 3, 10, 200)
# dt_long rmse mean: 1.9423324346542359
# dt_long rmse std: 0.39478051684061966
# dt_long average R^2 score: 0.5313427805900574
# dt_long R^2 score std: 0.33800175587987563
#
# param: (10, 3, 15, 100)
# dt_long rmse mean: 1.731320309638977
# dt_long rmse std: 0.41479716362779256
# dt_long average R^2 score: 0.6813052654266357
# dt_long R^2 score std: 0.1546892863366087
#
# param: (10, 3, 15, 200)
# dt_long rmse mean: 1.662382173538208
# dt_long rmse std: 0.3915749467428275
# dt_long average R^2 score: 0.7025638341903686
# dt_long R^2 score std: 0.15309729985222206
#
# param: (10, 3, 20, 100)
# dt_long rmse mean: 1.4785114407539368
# dt_long rmse std: 0.4141776057644033
# dt_long average R^2 score: 0.7644210577011108
# dt_long R^2 score std: 0.11830805486357111
#
# param: (10, 3, 20, 200)
# dt_long rmse mean: 1.4538706064224243
# dt_long rmse std: 0.39718710297562826
# dt_long average R^2 score: 0.7700527667999267
# dt_long R^2 score std: 0.11876693877680472
#
# param: (10, 5, 5, 100)
# dt_long rmse mean: 1.8294107913970947
# dt_long rmse std: 0.29155341765546344
# dt_long average R^2 score: 0.6231232523918152
# dt_long R^2 score std: 0.18556193688089723
#
# param: (10, 5, 5, 200)
# dt_long rmse mean: 1.7460402011871339
# dt_long rmse std: 0.25905292067186775
# dt_long average R^2 score: 0.6438181042671204
# dt_long R^2 score std: 0.2025287504106825
#
# param: (10, 5, 10, 100)
# dt_long rmse mean: 1.8335793018341064
# dt_long rmse std: 0.35092126384863837
# dt_long average R^2 score: 0.5993231058120727
# dt_long R^2 score std: 0.2606147736495199
#
# param: (10, 5, 10, 200)
# dt_long rmse mean: 1.8396999835968018
# dt_long rmse std: 0.3980570935735646
# dt_long average R^2 score: 0.578210997581482
# dt_long R^2 score std: 0.2898302302379518
#
# param: (10, 5, 15, 100)
# dt_long rmse mean: 1.666823673248291
# dt_long rmse std: 0.36621949921986857
# dt_long average R^2 score: 0.7027281403541565
# dt_long R^2 score std: 0.14012951201687576
#
# param: (10, 5, 15, 200)
# dt_long rmse mean: 1.648671269416809
# dt_long rmse std: 0.3725986925106363
# dt_long average R^2 score: 0.7073926448822021
# dt_long R^2 score std: 0.144228800368123
#
# param: (10, 5, 20, 100)
# dt_long rmse mean: 1.4247508287429809
# dt_long rmse std: 0.35040557516205245
# dt_long average R^2 score: 0.7887305498123169
# dt_long R^2 score std: 0.08303372836536815
#
# param: (10, 5, 20, 200)
# dt_long rmse mean: 1.4185691118240356
# dt_long rmse std: 0.38434341557785673
# dt_long average R^2 score: 0.7907994031906128
# dt_long R^2 score std: 0.08663671296053463
#
# param: (10, 10, 5, 100)
# dt_long rmse mean: 1.7310371160507203
# dt_long rmse std: 0.25134803281976
# dt_long average R^2 score: 0.6487204194068908
# dt_long R^2 score std: 0.18956332577461252
#
# param: (10, 10, 5, 200)
# dt_long rmse mean: 1.7676994800567627
# dt_long rmse std: 0.3272175315510211
# dt_long average R^2 score: 0.6277119398117066
# dt_long R^2 score std: 0.21171077865374419
#
# param: (10, 10, 10, 100)
# dt_long rmse mean: 1.7203978538513183
# dt_long rmse std: 0.3089139983271915
# dt_long average R^2 score: 0.6609240412712097
# dt_long R^2 score std: 0.1852869507882889
#
# param: (10, 10, 10, 200)
# dt_long rmse mean: 1.6831638097763062
# dt_long rmse std: 0.357000929064235
# dt_long average R^2 score: 0.6584867119789124
# dt_long R^2 score std: 0.21633060911217497
#
# param: (10, 10, 15, 100)
# dt_long rmse mean: 1.706386184692383
# dt_long rmse std: 0.2813900394606198
# dt_long average R^2 score: 0.6729111313819885
# dt_long R^2 score std: 0.17308211891803588
#
# param: (10, 10, 15, 200)
# dt_long rmse mean: 1.660968041419983
# dt_long rmse std: 0.27920463232641596
# dt_long average R^2 score: 0.6849609732627868
# dt_long R^2 score std: 0.17815816486930536
#
# param: (10, 10, 20, 100)
# dt_long rmse mean: 1.4621734380722047
# dt_long rmse std: 0.2935895572843349
# dt_long average R^2 score: 0.7679458260536194
# dt_long R^2 score std: 0.10831999080856408
#
# param: (10, 10, 20, 200)
# dt_long rmse mean: 1.4571247577667237
# dt_long rmse std: 0.28815238331738935
# dt_long average R^2 score: 0.768145489692688
# dt_long R^2 score std: 0.11029873077892048
#
# param: (10, 20, 5, 100)
# dt_long rmse mean: 1.7719549179077148
# dt_long rmse std: 0.25509052280053035
# dt_long average R^2 score: 0.6302972078323364
# dt_long R^2 score std: 0.20785892117839486
#
# param: (10, 20, 5, 200)
# dt_long rmse mean: 1.7364813327789306
# dt_long rmse std: 0.28962344392408795
# dt_long average R^2 score: 0.6452839493751525
# dt_long R^2 score std: 0.20322106031303733
#
# param: (10, 20, 10, 100)
# dt_long rmse mean: 1.7198670387268067
# dt_long rmse std: 0.19333318151728024
# dt_long average R^2 score: 0.6592739343643188
# dt_long R^2 score std: 0.1702504164008989
#
# param: (10, 20, 10, 200)
# dt_long rmse mean: 1.6051803827285767
# dt_long rmse std: 0.20558980507218846
# dt_long average R^2 score: 0.6932098746299744
# dt_long R^2 score std: 0.1694061131761857
#
# param: (10, 20, 15, 100)
# dt_long rmse mean: 1.7085958957672118
# dt_long rmse std: 0.33762804994932866
# dt_long average R^2 score: 0.6674882292747497
# dt_long R^2 score std: 0.20754780319686406
#
# param: (10, 20, 15, 200)
# dt_long rmse mean: 1.654629898071289
# dt_long rmse std: 0.3697051477292375
# dt_long average R^2 score: 0.6721098899841309
# dt_long R^2 score std: 0.23843873855595674
#
# param: (10, 20, 20, 100)
# dt_long rmse mean: 1.4779972553253173
# dt_long rmse std: 0.29408232914497384
# dt_long average R^2 score: 0.748495614528656
# dt_long R^2 score std: 0.1412346964583613
#
# param: (10, 20, 20, 200)
# dt_long rmse mean: 1.4366082191467284
# dt_long rmse std: 0.33117182783283927
# dt_long average R^2 score: 0.7497618079185486
# dt_long R^2 score std: 0.16219269649482768
#
# param: (20, 0, 5, 100)
# dt_long rmse mean: 1.6566244125366212
# dt_long rmse std: 0.1792705162823418
# dt_long average R^2 score: 0.6813481092453003
# dt_long R^2 score std: 0.1575926183328385
#
# param: (20, 0, 5, 200)
# dt_long rmse mean: 1.7772926330566405
# dt_long rmse std: 0.26941942472563546
# dt_long average R^2 score: 0.62052983045578
# dt_long R^2 score std: 0.2352429436343089
#
# param: (20, 0, 10, 100)
# dt_long rmse mean: 1.8614487886428832
# dt_long rmse std: 0.25891623665233293
# dt_long average R^2 score: 0.604127299785614
# dt_long R^2 score std: 0.21404267013383144
#
# param: (20, 0, 10, 200)
# dt_long rmse mean: 1.8985089302062987
# dt_long rmse std: 0.3726615454051197
# dt_long average R^2 score: 0.5758940696716308
# dt_long R^2 score std: 0.28820889608438083
#
# param: (20, 0, 15, 100)
# dt_long rmse mean: 1.5603102922439576
# dt_long rmse std: 0.25495709025561475
# dt_long average R^2 score: 0.735853123664856
# dt_long R^2 score std: 0.11730053632745846
#
# param: (20, 0, 15, 200)
# dt_long rmse mean: 1.5368138551712036
# dt_long rmse std: 0.2587614037192526
# dt_long average R^2 score: 0.7428222537040711
# dt_long R^2 score std: 0.11976563040053705
#
# param: (20, 0, 20, 100)
# dt_long rmse mean: 1.4932657957077027
# dt_long rmse std: 0.26010089505684214
# dt_long average R^2 score: 0.7507898688316346
# dt_long R^2 score std: 0.11738821076388672
#
# param: (20, 0, 20, 200)
# dt_long rmse mean: 1.4912529230117797
# dt_long rmse std: 0.27955302144959016
# dt_long average R^2 score: 0.7516995072364807
# dt_long R^2 score std: 0.11954809435798046
#
# param: (20, 1, 5, 100)
# dt_long rmse mean: 1.7661688089370728
# dt_long rmse std: 0.19838239959189333
# dt_long average R^2 score: 0.6401663422584534
# dt_long R^2 score std: 0.17607383019416287
#
# param: (20, 1, 5, 200)
# dt_long rmse mean: 1.7919801950454712
# dt_long rmse std: 0.20101152096309913
# dt_long average R^2 score: 0.6119294881820678
# dt_long R^2 score std: 0.21351301948728807
#
# param: (20, 1, 10, 100)
# dt_long rmse mean: 1.8126853704452515
# dt_long rmse std: 0.2978799875424595
# dt_long average R^2 score: 0.6353145837783813
# dt_long R^2 score std: 0.1892957737296305
#
# param: (20, 1, 10, 200)
# dt_long rmse mean: 1.837776255607605
# dt_long rmse std: 0.3436533856669568
# dt_long average R^2 score: 0.617438268661499
# dt_long R^2 score std: 0.2305233434859168
#
# param: (20, 1, 15, 100)
# dt_long rmse mean: 1.6136796951293946
# dt_long rmse std: 0.27168392801140007
# dt_long average R^2 score: 0.70692138671875
# dt_long R^2 score std: 0.14465517849741316
#
# param: (20, 1, 15, 200)
# dt_long rmse mean: 1.616563892364502
# dt_long rmse std: 0.2791674531352799
# dt_long average R^2 score: 0.7084541916847229
# dt_long R^2 score std: 0.1402114095676202
#
# param: (20, 1, 20, 100)
# dt_long rmse mean: 1.4994174480438232
# dt_long rmse std: 0.27105616371653696
# dt_long average R^2 score: 0.7321528673171998
# dt_long R^2 score std: 0.14824386819989802
#
# param: (20, 1, 20, 200)
# dt_long rmse mean: 1.529061508178711
# dt_long rmse std: 0.2993672698317671
# dt_long average R^2 score: 0.7294129490852356
# dt_long R^2 score std: 0.14499925493658486
#
# param: (20, 3, 5, 100)
# dt_long rmse mean: 1.7419534921646118
# dt_long rmse std: 0.22154975767620638
# dt_long average R^2 score: 0.652534294128418
# dt_long R^2 score std: 0.1716829708269081
#
# param: (20, 3, 5, 200)
# dt_long rmse mean: 1.732037901878357
# dt_long rmse std: 0.23374038532983088
# dt_long average R^2 score: 0.6501173973083496
# dt_long R^2 score std: 0.19842126837583413
#
# param: (20, 3, 10, 100)
# dt_long rmse mean: 1.8549408674240113
# dt_long rmse std: 0.2486149599978281
# dt_long average R^2 score: 0.6126378417015076
# dt_long R^2 score std: 0.18665979759214346
#
# param: (20, 3, 10, 200)
# dt_long rmse mean: 1.843868327140808
# dt_long rmse std: 0.286062687898935
# dt_long average R^2 score: 0.6032701373100281
# dt_long R^2 score std: 0.22422443706633302
#
# param: (20, 3, 15, 100)
# dt_long rmse mean: 1.5751607179641725
# dt_long rmse std: 0.2552199233489257
# dt_long average R^2 score: 0.7055134773254395
# dt_long R^2 score std: 0.16616737930923442
#
# param: (20, 3, 15, 200)
# dt_long rmse mean: 1.5598075628280639
# dt_long rmse std: 0.30163850465408487
# dt_long average R^2 score: 0.7197790503501892
# dt_long R^2 score std: 0.15876386652016078
#
# param: (20, 3, 20, 100)
# dt_long rmse mean: 1.5070595026016236
# dt_long rmse std: 0.2983371466538555
# dt_long average R^2 score: 0.7464248299598694
# dt_long R^2 score std: 0.12327047685444385
#
# param: (20, 3, 20, 200)
# dt_long rmse mean: 1.5156866312026978
# dt_long rmse std: 0.32232283409445694
# dt_long average R^2 score: 0.7457844734191894
# dt_long R^2 score std: 0.12298026489439826
#
# param: (20, 5, 5, 100)
# dt_long rmse mean: 1.796350884437561
# dt_long rmse std: 0.282347565714079
# dt_long average R^2 score: 0.6328162431716919
# dt_long R^2 score std: 0.18983979852810243
#
# param: (20, 5, 5, 200)
# dt_long rmse mean: 1.8286689281463624
# dt_long rmse std: 0.31358674008044635
# dt_long average R^2 score: 0.6068752765655517
# dt_long R^2 score std: 0.23415351996377926
#
# param: (20, 5, 10, 100)
# dt_long rmse mean: 1.7290283203125
# dt_long rmse std: 0.27803502708968914
# dt_long average R^2 score: 0.6652715921401977
# dt_long R^2 score std: 0.16506146260483945
#
# param: (20, 5, 10, 200)
# dt_long rmse mean: 1.6680359601974488
# dt_long rmse std: 0.25007918627040293
# dt_long average R^2 score: 0.6787206888198852
# dt_long R^2 score std: 0.1708321352103671
#
# param: (20, 5, 15, 100)
# dt_long rmse mean: 1.5363200187683106
# dt_long rmse std: 0.26140189555686305
# dt_long average R^2 score: 0.7329319238662719
# dt_long R^2 score std: 0.13868966103269195
#
# param: (20, 5, 15, 200)
# dt_long rmse mean: 1.4993497371673583
# dt_long rmse std: 0.2736328130069904
# dt_long average R^2 score: 0.7392852306365967
# dt_long R^2 score std: 0.15150007026490817
#
# param: (20, 5, 20, 100)
# dt_long rmse mean: 1.4490724563598634
# dt_long rmse std: 0.31054267576053346
# dt_long average R^2 score: 0.7596145868301392
# dt_long R^2 score std: 0.1390587142204621
#
# param: (20, 5, 20, 200)
# dt_long rmse mean: 1.4514512538909912
# dt_long rmse std: 0.3311930962779193
# dt_long average R^2 score: 0.7605718612670899
# dt_long R^2 score std: 0.13709289653606863
#
# param: (20, 10, 5, 100)
# dt_long rmse mean: 1.7502156496047974
# dt_long rmse std: 0.22331644965966868
# dt_long average R^2 score: 0.6552562236785888
# dt_long R^2 score std: 0.16229520800222225
#
# param: (20, 10, 5, 200)
# dt_long rmse mean: 1.7311753988265992
# dt_long rmse std: 0.27326816055171926
# dt_long average R^2 score: 0.6549822688102722
# dt_long R^2 score std: 0.18728969841111545
#
# param: (20, 10, 10, 100)
# dt_long rmse mean: 1.724414086341858
# dt_long rmse std: 0.24668422879795138
# dt_long average R^2 score: 0.6520838618278504
# dt_long R^2 score std: 0.19669829915992917
#
# param: (20, 10, 10, 200)
# dt_long rmse mean: 1.7957366466522218
# dt_long rmse std: 0.336513787532789
# dt_long average R^2 score: 0.6145225882530212
# dt_long R^2 score std: 0.23173045210103982
#
# param: (20, 10, 15, 100)
# dt_long rmse mean: 1.5014258861541747
# dt_long rmse std: 0.19730910611918934
# dt_long average R^2 score: 0.7377869844436645
# dt_long R^2 score std: 0.13348081214768454
#
# param: (20, 10, 15, 200)
# dt_long rmse mean: 1.4652239322662353
# dt_long rmse std: 0.22014487900055485
# dt_long average R^2 score: 0.7462336659431458
# dt_long R^2 score std: 0.13929911355145477
#
# param: (20, 10, 20, 100)
# dt_long rmse mean: 1.483114767074585
# dt_long rmse std: 0.25744278036421414
# dt_long average R^2 score: 0.7451572895050049
# dt_long R^2 score std: 0.1349172024963676
#
# param: (20, 10, 20, 200)
# dt_long rmse mean: 1.4743804931640625
# dt_long rmse std: 0.26569410180403025
# dt_long average R^2 score: 0.7494698882102966
# dt_long R^2 score std: 0.13226005535566
#
# param: (20, 20, 5, 100)
# dt_long rmse mean: 1.7256761074066163
# dt_long rmse std: 0.29785974780433466
# dt_long average R^2 score: 0.65557359457016
# dt_long R^2 score std: 0.18540079923170572
#
# param: (20, 20, 5, 200)
# dt_long rmse mean: 1.6934302568435669
# dt_long rmse std: 0.27697828828682086
# dt_long average R^2 score: 0.6625689506530762
# dt_long R^2 score std: 0.19199296388885143
#
# param: (20, 20, 10, 100)
# dt_long rmse mean: 1.7606120347976684
# dt_long rmse std: 0.23583199262678012
# dt_long average R^2 score: 0.6337379455566406
# dt_long R^2 score std: 0.21218913628883318
#
# param: (20, 20, 10, 200)
# dt_long rmse mean: 1.6997694969177246
# dt_long rmse std: 0.25351523671244414
# dt_long average R^2 score: 0.6503584861755372
# dt_long R^2 score std: 0.21530698928919043
#
# param: (20, 20, 15, 100)
# dt_long rmse mean: 1.5378939628601074
# dt_long rmse std: 0.22964709147435824
# dt_long average R^2 score: 0.7416811943054199
# dt_long R^2 score std: 0.11180386940621481
#
# param: (20, 20, 15, 200)
# dt_long rmse mean: 1.507723045349121
# dt_long rmse std: 0.20340377498148549
# dt_long average R^2 score: 0.7467806100845337
# dt_long R^2 score std: 0.11626431974357909
#
# param: (20, 20, 20, 100)
# dt_long rmse mean: 1.5633685350418092
# dt_long rmse std: 0.21547564552618842
# dt_long average R^2 score: 0.7229158997535705
# dt_long R^2 score std: 0.13314940145039533
#
# param: (20, 20, 20, 200)
# dt_long rmse mean: 1.5345098972320557
# dt_long rmse std: 0.22543286846621183
# dt_long average R^2 score: 0.727614414691925
# dt_long R^2 score std: 0.14052027843543843

# %%
best_loss = np.inf
best_R2 = 0
best_loss_param = (0,0,0,0)
best_R2_param = (0,0,0,0)
for param in params.keys():
    curr_loss = np.array([loss[param, idx] for idx in range(5)]).mean()
    curr_R2 = np.array([R2_score[param, idx] for idx in range(5)]).mean()
    if curr_loss < best_loss:
        best_loss = loss[param, idx]
        best_loss_param = param
    if curr_R2 > best_R2:
        best_R2 = curr_R2
        best_R2_param = param

print(best_loss, best_loss_param, best_R2, best_R2_param)
print([loss[best_loss_param, idx] for idx in range(5)])
print([R2_score[best_loss_param, idx] for idx in range(5)])

print([loss[best_R2_param, idx] for idx in range(5)])
print([R2_score[best_R2_param, idx] for idx in range(5)])
# Out:
# 1.7135766744613647 (20, 20, 20, 200) 0.7907994031906128 (10, 5, 20, 200)
# [1.6935337781906128, 1.7380448579788208, 1.197967529296875, 1.329426646232605, 1.7135766744613647]
# [0.6476107835769653, 0.5176153182983398, 0.873482882976532, 0.708674430847168, 0.8906886577606201]
# [1.4735350608825684, 1.4601510763168335, 1.0096664428710938, 1.0658924579620361, 2.0836005210876465]
# [0.7332184314727783, 0.6595391631126404, 0.910129964351654, 0.8127263784408569, 0.8383830785751343]

# %% [markdown]
# Actually, the second model does pretty well in general, so I think I will use these parameters for my final analysis.

# %%
df_filter = dict()
y_filter = dict()
X_filter= dict()
features = ['bunch', 'avg_wind_speed', 'avg_visibility', 'avg_health_index', 'rain', 'snow_on_ground', 'daylight', 'dir', 'stop']
for target in ['dt_short', 'dt_long']:
    df_filter[target] = daily_df
    X_filter[target] = df_filter[target][[x for x in features]]
    y_filter[target] = df_filter[target][target]

model_filter = dict()
for key in df_filter.keys():
    model_filter[key] = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100,
    learning_rate=0.1,
    enable_categorical=True,
    max_depth=5,
    reg_lambda=4,
    reg_alpha=0,
    seed=37)
    model_filter[key].fit(X_filter[key], y_filter[key])

explainer_filter = dict()
shap_filter = dict()
for key in df_filter.keys():
    explainer_filter[key] = shap.Explainer(model_filter[key])
    shap_filter[key] = explainer_filter[key](X_filter[key])

for key in df_filter.keys():
    shap.plots.bar(shap_filter[key], show=False)
    plt.title(str(key))
    plt.show()

# %% [markdown]
# Finally, we can look at the distribution of the features.

# %%
for key in df_filter.keys():
    shap.plots.beeswarm(shap_filter[key], show=False)
    plt.title(str(key))
    plt.show()

# %% [markdown]
# In fact, the short term delay time is also a strong predictor for the amount of gap events, suggesting that gap does not make a good feature for prediction.

# %%
loss = dict()
R2_score = dict()
features = ['dt_short', 'dir', 'stop']

tss = TimeSeriesSplit(n_splits=5, test_size=30)
for target in ['bunch','gap']:
    for idx, (tss_train, tss_test) in enumerate(tss.split(daily_df, daily_df.date)):
        df_train = daily_df.iloc[tss_train]
        df_test = daily_df.iloc[tss_test]

        model = xgb.XGBRegressor(objective='reg:squarederror',
                                n_estimators=100,
                                enable_categorical=True,
                                learning_rate=0.1,
                                max_depth=10,
                                reg_lambda=5,
                                reg_alpha=0,
                                seed=37)

        X_train = df_train[features]
        y_train = df_train[target]
        X_test = df_test[features]
        y_test = df_test[target]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        R2_score[target,idx] = r2_score(y_test, y_pred)
        loss[target,idx] = rmse(y_test, y_pred)

for dt in ['bunch','gap']:
    print(f'{dt} rmse mean: {np.array([val for key,val in loss.items() if key[0] == dt]).mean()}')
    print(f'{dt} rmse std: {np.array([val for key,val in loss.items() if key[0] == dt]).std()}')
    print(f'{dt} average R^2 score: {np.array([val for key,val in R2_score.items() if key[0] == dt]).mean()}')
    print(f'{dt} R^2 score std: {np.array([val for key,val in R2_score.items() if key[0] == dt]).std()}\n')

# %% [markdown]
# Some hyperparameter tuning to try to see if 'bunch' can be predicted from the above information.

# %%
loss = dict()
R2_score = dict()
features = ['dt_short', 'dir', 'stop']

tss = TimeSeriesSplit(n_splits=5, test_size=30)
target = 'bunch'
lambda_vals = [0,1,3,5,10,20]
alpha_vals = [0,1,3,5,10,20]
depth_vals = [5,10,15,20]
est_vals = [100,200]

params = dict()
for l in lambda_vals:
    for a in alpha_vals:
        for d in depth_vals:
            for n in est_vals:
                params[l,a,d,n] = (l,a,d,n)

for param in params.keys():
    for idx, (tss_train, tss_test) in enumerate(tss.split(daily_df, daily_df.date)):
        df_train = daily_df.iloc[tss_train]
        df_test = daily_df.iloc[tss_test]

        model = xgb.XGBRegressor(objective='reg:squarederror',
                                n_estimators=param[3],
                                enable_categorical=True,
                                learning_rate=0.1,
                                max_depth=param[2],
                                reg_lambda=param[0],
                                reg_alpha=param[1],
                                seed=37)

        X_train = df_train[features]
        y_train = df_train[target]
        X_test = df_test[features]
        y_test = df_test[target]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        R2_score[param,idx] = r2_score(y_test, y_pred)
        loss[param,idx] = rmse(y_test, y_pred)

# %%
for param in params.keys():
    print(f'param: {param}')
    print(f'{target} rmse mean: {np.array([val for key,val in loss.items() if key[0] == param]).mean()}')
    print(f'{target} rmse std: {np.array([val for key,val in loss.items() if key[0] == param]).std()}')
    print(f'{target} average R^2 score: {np.array([val for key,val in R2_score.items() if key[0] == param]).mean()}')
    print(f'{target} R^2 score std: {np.array([val for key,val in R2_score.items() if key[0] == param]).std()}\n')

best_loss = np.inf
best_R2 = 0
best_loss_param = (0,0,0,0)
best_R2_param = (0,0,0,0)
for param in params.keys():
    curr_loss = np.array([loss[param, idx] for idx in range(5)]).mean()
    curr_R2 = np.array([R2_score[param, idx] for idx in range(5)]).mean()
    if curr_loss < best_loss:
        best_loss = loss[param, idx]
        best_loss_param = param
    if curr_R2 > best_R2:
        best_R2 = curr_R2
        best_R2_param = param

# %%
print(best_loss, best_loss_param, best_R2, best_R2_param)
print([loss[best_loss_param, idx] for idx in range(5)])
print([R2_score[best_loss_param, idx] for idx in range(5)])

print([loss[best_R2_param, idx] for idx in range(5)])
print([R2_score[best_R2_param, idx] for idx in range(5)])
# Out:
# 2.6541495323181152 (1, 20, 5, 100) 0.47823084592819215 (20, 20, 5, 200)
# [2.8886983394622803, 3.2354393005371094, 2.429004192352295, 3.3638415336608887, 2.6541495323181152]
# [0.5337935090065002, 0.42553287744522095, 0.6282776594161987, 0.29771143198013306, 0.505494236946106]
# [2.8359384536743164, 3.2145724296569824, 2.4297876358032227, 3.375271797180176, 2.7043824195861816]
# [0.5506678819656372, 0.4329190254211426, 0.6280378103256226, 0.29293060302734375, 0.4865989089012146]

# %% [markdown]
# This is pretty bad, which adds to evidence that bunch events alone cannot predict delays. Finally, we try the other way around.

# %%
loss = dict()
R2_score = dict()
features = ['bunch', 'dir', 'stop']

tss = TimeSeriesSplit(n_splits=5, test_size=30)
target = 'dt_short'
lambda_vals = [0,1,3,5,10,20]
alpha_vals = [0,1,3,5,10,20]
depth_vals = [5,10,15,20]
est_vals = [100,200]

params = dict()
for l in lambda_vals:
    for a in alpha_vals:
        for d in depth_vals:
            for n in est_vals:
                params[l,a,d,n] = (l,a,d,n)

for param in params.keys():
    for idx, (tss_train, tss_test) in enumerate(tss.split(daily_df, daily_df.date)):
        df_train = daily_df.iloc[tss_train]
        df_test = daily_df.iloc[tss_test]

        model = xgb.XGBRegressor(objective='reg:squarederror',
                                n_estimators=param[3],
                                enable_categorical=True,
                                learning_rate=0.1,
                                max_depth=param[2],
                                reg_lambda=param[0],
                                reg_alpha=param[1],
                                seed=37)

        X_train = df_train[features]
        y_train = df_train[target]
        X_test = df_test[features]
        y_test = df_test[target]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        R2_score[param,idx] = r2_score(y_test, y_pred)
        loss[param,idx] = rmse(y_test, y_pred)

# %%
for param in params.keys():
    print(f'param: {param}')
    print(f'{target} rmse mean: {np.array([val for key,val in loss.items() if key[0] == param]).mean()}')
    print(f'{target} rmse std: {np.array([val for key,val in loss.items() if key[0] == param]).std()}')
    print(f'{target} average R^2 score: {np.array([val for key,val in R2_score.items() if key[0] == param]).mean()}')
    print(f'{target} R^2 score std: {np.array([val for key,val in R2_score.items() if key[0] == param]).std()}\n')

best_loss = np.inf
best_R2 = 0
best_loss_param = (0,0,0,0)
best_R2_param = (0,0,0,0)
for param in params.keys():
    curr_loss = np.array([loss[param, idx] for idx in range(5)]).mean()
    curr_R2 = np.array([R2_score[param, idx] for idx in range(5)]).mean()
    if curr_loss < best_loss:
        best_loss = loss[param, idx]
        best_loss_param = param
    if curr_R2 > best_R2:
        best_R2 = curr_R2
        best_R2_param = param
# Out:
# param: (0, 0, 5, 100)
# dt_short rmse mean: 8.081249618530274
# dt_short rmse std: 1.23688018869089
# dt_short average R^2 score: 0.6487087488174439
# dt_short R^2 score std: 0.10133567286736762
#
# param: (0, 0, 5, 200)
# dt_short rmse mean: 8.07810869216919
# dt_short rmse std: 1.2489685577097729
# dt_short average R^2 score: 0.6488785028457642
# dt_short R^2 score std: 0.10178675445058415
#
# param: (0, 0, 10, 100)
# dt_short rmse mean: 8.119351863861084
# dt_short rmse std: 1.3229996250046814
# dt_short average R^2 score: 0.6441850543022156
# dt_short R^2 score std: 0.10859749742476774
#
# param: (0, 0, 10, 200)
# dt_short rmse mean: 8.12428789138794
# dt_short rmse std: 1.327149169403992
# dt_short average R^2 score: 0.6436891794204712
# dt_short R^2 score std: 0.10912764231206493
#
# param: (0, 0, 15, 100)
# dt_short rmse mean: 8.124407768249512
# dt_short rmse std: 1.3272204191322663
# dt_short average R^2 score: 0.643677020072937
# dt_short R^2 score std: 0.10913987446798629
#
# param: (0, 0, 15, 200)
# dt_short rmse mean: 8.124317646026611
# dt_short rmse std: 1.3272076386733769
# dt_short average R^2 score: 0.6436848282814026
# dt_short R^2 score std: 0.10913777673666378
#
# param: (0, 0, 20, 100)
# dt_short rmse mean: 8.12440366744995
# dt_short rmse std: 1.3272192040293553
# dt_short average R^2 score: 0.6436773657798767
# dt_short R^2 score std: 0.10913988484206359
#
# param: (0, 0, 20, 200)
# dt_short rmse mean: 8.124316883087157
# dt_short rmse std: 1.3272086815874449
# dt_short average R^2 score: 0.6436848640441895
# dt_short R^2 score std: 0.10913799614017754
#
# param: (0, 1, 5, 100)
# dt_short rmse mean: 8.076193618774415
# dt_short rmse std: 1.2573411897436741
# dt_short average R^2 score: 0.6488263726234436
# dt_short R^2 score std: 0.10299200425657172
#
# param: (0, 1, 5, 200)
# dt_short rmse mean: 8.070102882385253
# dt_short rmse std: 1.2858527309091912
# dt_short average R^2 score: 0.6490825295448304
# dt_short R^2 score std: 0.10520364185607108
#
# param: (0, 1, 10, 100)
# dt_short rmse mean: 8.11857204437256
# dt_short rmse std: 1.3232179684297538
# dt_short average R^2 score: 0.6442610740661621
# dt_short R^2 score std: 0.1085694760680652
#
# param: (0, 1, 10, 200)
# dt_short rmse mean: 8.123103904724122
# dt_short rmse std: 1.3265741011416952
# dt_short average R^2 score: 0.6438025236129761
# dt_short R^2 score std: 0.10905750179167897
#
# param: (0, 1, 15, 100)
# dt_short rmse mean: 8.125240230560303
# dt_short rmse std: 1.3255253660481487
# dt_short average R^2 score: 0.6436381220817566
# dt_short R^2 score std: 0.10894896707237793
#
# param: (0, 1, 15, 200)
# dt_short rmse mean: 8.12633581161499
# dt_short rmse std: 1.3260315567192726
# dt_short average R^2 score: 0.6435327172279358
# dt_short R^2 score std: 0.10903158148864933
#
# param: (0, 1, 20, 100)
# dt_short rmse mean: 8.124242401123047
# dt_short rmse std: 1.32634829778417
# dt_short average R^2 score: 0.6437090873718262
# dt_short R^2 score std: 0.10903614608256698
#
# param: (0, 1, 20, 200)
# dt_short rmse mean: 8.124942874908447
# dt_short rmse std: 1.32653182123219
# dt_short average R^2 score: 0.6436421155929566
# dt_short R^2 score std: 0.1090788827280144
#
# param: (0, 3, 5, 100)
# dt_short rmse mean: 8.057693672180175
# dt_short rmse std: 1.25452594221186
# dt_short average R^2 score: 0.6504870295524597
# dt_short R^2 score std: 0.10241249085132204
#
# param: (0, 3, 5, 200)
# dt_short rmse mean: 8.065383243560792
# dt_short rmse std: 1.2781076460019498
# dt_short average R^2 score: 0.6495112419128418
# dt_short R^2 score std: 0.10464928062992639
#
# param: (0, 3, 10, 100)
# dt_short rmse mean: 8.114664459228516
# dt_short rmse std: 1.3141514570345254
# dt_short average R^2 score: 0.6447236657142639
# dt_short R^2 score std: 0.10783534553659946
#
# param: (0, 3, 10, 200)
# dt_short rmse mean: 8.123561096191406
# dt_short rmse std: 1.3202049962737274
# dt_short average R^2 score: 0.643856942653656
# dt_short R^2 score std: 0.10856271780917234
#
# param: (0, 3, 15, 100)
# dt_short rmse mean: 8.1230863571167
# dt_short rmse std: 1.321627603275815
# dt_short average R^2 score: 0.6438732504844665
# dt_short R^2 score std: 0.10860193052176574
#
# param: (0, 3, 15, 200)
# dt_short rmse mean: 8.12420482635498
# dt_short rmse std: 1.323588338267755
# dt_short average R^2 score: 0.6437426805496216
# dt_short R^2 score std: 0.10880921884241629
#
# param: (0, 3, 20, 100)
# dt_short rmse mean: 8.124574184417725
# dt_short rmse std: 1.3255358654859062
# dt_short average R^2 score: 0.6436931490898132
# dt_short R^2 score std: 0.10899854458693235
#
# param: (0, 3, 20, 200)
# dt_short rmse mean: 8.125860786437988
# dt_short rmse std: 1.3261764951900918
# dt_short average R^2 score: 0.6435679793357849
# dt_short R^2 score std: 0.10908325980102095
#
# param: (0, 5, 5, 100)
# dt_short rmse mean: 8.033113861083985
# dt_short rmse std: 1.2520732724086916
# dt_short average R^2 score: 0.6526338577270507
# dt_short R^2 score std: 0.10200230948460506
#
# param: (0, 5, 5, 200)
# dt_short rmse mean: 8.023681640625
# dt_short rmse std: 1.2975376960225196
# dt_short average R^2 score: 0.6529219150543213
# dt_short R^2 score std: 0.10596894155615849
#
# param: (0, 5, 10, 100)
# dt_short rmse mean: 8.107616519927978
# dt_short rmse std: 1.3111852458316655
# dt_short average R^2 score: 0.6453504920005798
# dt_short R^2 score std: 0.10773051541989029
#
# param: (0, 5, 10, 200)
# dt_short rmse mean: 8.119999599456786
# dt_short rmse std: 1.3195740821774016
# dt_short average R^2 score: 0.6441787004470825
# dt_short R^2 score std: 0.10865190303273613
#
# param: (0, 5, 15, 100)
# dt_short rmse mean: 8.119765949249267
# dt_short rmse std: 1.3205659612035427
# dt_short average R^2 score: 0.6441956877708435
# dt_short R^2 score std: 0.10853634037739901
#
# param: (0, 5, 15, 200)
# dt_short rmse mean: 8.122514343261718
# dt_short rmse std: 1.3224759361751972
# dt_short average R^2 score: 0.6439263582229614
# dt_short R^2 score std: 0.10876587042175943
#
# param: (0, 5, 20, 100)
# dt_short rmse mean: 8.118367290496826
# dt_short rmse std: 1.323648443454963
# dt_short average R^2 score: 0.644277024269104
# dt_short R^2 score std: 0.10874216863993362
#
# param: (0, 5, 20, 200)
# dt_short rmse mean: 8.121647357940674
# dt_short rmse std: 1.3251374257399275
# dt_short average R^2 score: 0.6439576268196106
# dt_short R^2 score std: 0.10896111226583478
#
# param: (0, 10, 5, 100)
# dt_short rmse mean: 8.067557239532471
# dt_short rmse std: 1.284692651332368
# dt_short average R^2 score: 0.6492495656013488
# dt_short R^2 score std: 0.10545855360604518
#
# param: (0, 10, 5, 200)
# dt_short rmse mean: 8.066200828552246
# dt_short rmse std: 1.3133355132188034
# dt_short average R^2 score: 0.6489378571510315
# dt_short R^2 score std: 0.10794572262899368
#
# param: (0, 10, 10, 100)
# dt_short rmse mean: 8.11490707397461
# dt_short rmse std: 1.295289070097897
# dt_short average R^2 score: 0.6449802041053772
# dt_short R^2 score std: 0.1063053983384781
#
# param: (0, 10, 10, 200)
# dt_short rmse mean: 8.116760158538819
# dt_short rmse std: 1.3118406745141016
# dt_short average R^2 score: 0.6446003198623658
# dt_short R^2 score std: 0.10790387371631019
#
# param: (0, 10, 15, 100)
# dt_short rmse mean: 8.105099964141846
# dt_short rmse std: 1.316038354939109
# dt_short average R^2 score: 0.6455381989479065
# dt_short R^2 score std: 0.10796447222487708
#
# param: (0, 10, 15, 200)
# dt_short rmse mean: 8.109581184387206
# dt_short rmse std: 1.3181802078861458
# dt_short average R^2 score: 0.6451131463050842
# dt_short R^2 score std: 0.1082049258696808
#
# param: (0, 10, 20, 100)
# dt_short rmse mean: 8.116885375976562
# dt_short rmse std: 1.317599764702383
# dt_short average R^2 score: 0.6445321202278137
# dt_short R^2 score std: 0.10823865544107326
#
# param: (0, 10, 20, 200)
# dt_short rmse mean: 8.118644618988037
# dt_short rmse std: 1.3187951857764484
# dt_short average R^2 score: 0.6443409085273742
# dt_short R^2 score std: 0.10840475891463398
#
# param: (0, 20, 5, 100)
# dt_short rmse mean: 8.057328796386718
# dt_short rmse std: 1.2574654268192316
# dt_short average R^2 score: 0.6504583358764648
# dt_short R^2 score std: 0.10310292297535471
#
# param: (0, 20, 5, 200)
# dt_short rmse mean: 8.05691385269165
# dt_short rmse std: 1.2810649091129163
# dt_short average R^2 score: 0.6501705169677734
# dt_short R^2 score std: 0.10517994269785184
#
# param: (0, 20, 10, 100)
# dt_short rmse mean: 8.080016899108887
# dt_short rmse std: 1.2786053118387544
# dt_short average R^2 score: 0.6482872128486633
# dt_short R^2 score std: 0.10437850538261247
#
# param: (0, 20, 10, 200)
# dt_short rmse mean: 8.088006973266602
# dt_short rmse std: 1.2906307820589766
# dt_short average R^2 score: 0.6474081993103027
# dt_short R^2 score std: 0.10565457613494898
#
# param: (0, 20, 15, 100)
# dt_short rmse mean: 8.101975440979004
# dt_short rmse std: 1.3054368427448952
# dt_short average R^2 score: 0.646013057231903
# dt_short R^2 score std: 0.10695398191424352
#
# param: (0, 20, 15, 200)
# dt_short rmse mean: 8.104135227203368
# dt_short rmse std: 1.3092765437419343
# dt_short average R^2 score: 0.6457592606544494
# dt_short R^2 score std: 0.10742542901435088
#
# param: (0, 20, 20, 100)
# dt_short rmse mean: 8.09400815963745
# dt_short rmse std: 1.3064782958738093
# dt_short average R^2 score: 0.6467324733734131
# dt_short R^2 score std: 0.10693359090435367
#
# param: (0, 20, 20, 200)
# dt_short rmse mean: 8.096864223480225
# dt_short rmse std: 1.3082779264980995
# dt_short average R^2 score: 0.6464276194572449
# dt_short R^2 score std: 0.10723917034653518
#
# param: (1, 0, 5, 100)
# dt_short rmse mean: 8.078791046142578
# dt_short rmse std: 1.2304928086169287
# dt_short average R^2 score: 0.6489640593528747
# dt_short R^2 score std: 0.10065395855561206
#
# param: (1, 0, 5, 200)
# dt_short rmse mean: 8.07810707092285
# dt_short rmse std: 1.2732270073471041
# dt_short average R^2 score: 0.6484881520271302
# dt_short R^2 score std: 0.10450237845956341
#
# param: (1, 0, 10, 100)
# dt_short rmse mean: 8.108646774291993
# dt_short rmse std: 1.3223718368231658
# dt_short average R^2 score: 0.6451212882995605
# dt_short R^2 score std: 0.108235613405188
#
# param: (1, 0, 10, 200)
# dt_short rmse mean: 8.124077892303466
# dt_short rmse std: 1.3272320757616478
# dt_short average R^2 score: 0.6437079548835755
# dt_short R^2 score std: 0.10912573749382791
#
# param: (1, 0, 15, 100)
# dt_short rmse mean: 8.124243259429932
# dt_short rmse std: 1.3272133225590776
# dt_short average R^2 score: 0.6436918377876282
# dt_short R^2 score std: 0.10913731053353148
#
# param: (1, 0, 15, 200)
# dt_short rmse mean: 8.124317646026611
# dt_short rmse std: 1.3272119870925285
# dt_short average R^2 score: 0.6436848640441895
# dt_short R^2 score std: 0.10913833221936765
#
# param: (1, 0, 20, 100)
# dt_short rmse mean: 8.124369144439697
# dt_short rmse std: 1.327216126626224
# dt_short average R^2 score: 0.6436805844306945
# dt_short R^2 score std: 0.10913893040308124
#
# param: (1, 0, 20, 200)
# dt_short rmse mean: 8.124318695068359
# dt_short rmse std: 1.3272026584748449
# dt_short average R^2 score: 0.6436847686767578
# dt_short R^2 score std: 0.10913742903169693
#
# param: (1, 1, 5, 100)
# dt_short rmse mean: 8.098376560211182
# dt_short rmse std: 1.2123420929038686
# dt_short average R^2 score: 0.6474750280380249
# dt_short R^2 score std: 0.09910581416464992
#
# param: (1, 1, 5, 200)
# dt_short rmse mean: 8.088771343231201
# dt_short rmse std: 1.2442851416466678
# dt_short average R^2 score: 0.6479079484939575
# dt_short R^2 score std: 0.10173274205043621
#
# param: (1, 1, 10, 100)
# dt_short rmse mean: 8.111581611633301
# dt_short rmse std: 1.3184351552400793
# dt_short average R^2 score: 0.6449154376983642
# dt_short R^2 score std: 0.10801481947891926
#
# param: (1, 1, 10, 200)
# dt_short rmse mean: 8.122884750366211
# dt_short rmse std: 1.3216279207873507
# dt_short average R^2 score: 0.6438941717147827
# dt_short R^2 score std: 0.10860850340900453
#
# param: (1, 1, 15, 100)
# dt_short rmse mean: 8.124837017059326
# dt_short rmse std: 1.3269438488109093
# dt_short average R^2 score: 0.6436540961265564
# dt_short R^2 score std: 0.10913357154812175
#
# param: (1, 1, 15, 200)
# dt_short rmse mean: 8.125971221923828
# dt_short rmse std: 1.3270204755680644
# dt_short average R^2 score: 0.6435484647750854
# dt_short R^2 score std: 0.10916045903330084
#
# param: (1, 1, 20, 100)
# dt_short rmse mean: 8.124828720092774
# dt_short rmse std: 1.3264857172427285
# dt_short average R^2 score: 0.6436574816703796
# dt_short R^2 score std: 0.1090709066808228
#
# param: (1, 1, 20, 200)
# dt_short rmse mean: 8.126059341430665
# dt_short rmse std: 1.3273217335120528
# dt_short average R^2 score: 0.6435358762741089
# dt_short R^2 score std: 0.10917623379557309
#
# param: (1, 3, 5, 100)
# dt_short rmse mean: 8.058188533782959
# dt_short rmse std: 1.2259893336259995
# dt_short average R^2 score: 0.6508347034454346
# dt_short R^2 score std: 0.0997918761460601
#
# param: (1, 3, 5, 200)
# dt_short rmse mean: 8.068272399902344
# dt_short rmse std: 1.2581078784785344
# dt_short average R^2 score: 0.64953533411026
# dt_short R^2 score std: 0.10262100460199447
#
# param: (1, 3, 10, 100)
# dt_short rmse mean: 8.106604099273682
# dt_short rmse std: 1.3111234911979153
# dt_short average R^2 score: 0.645470130443573
# dt_short R^2 score std: 0.10753618735829153
#
# param: (1, 3, 10, 200)
# dt_short rmse mean: 8.12141456604004
# dt_short rmse std: 1.3223631056058176
# dt_short average R^2 score: 0.644025468826294
# dt_short R^2 score std: 0.10882474757538792
#
# param: (1, 3, 15, 100)
# dt_short rmse mean: 8.121159934997559
# dt_short rmse std: 1.3193694468688015
# dt_short average R^2 score: 0.6440784215927124
# dt_short R^2 score std: 0.10837401660992736
#
# param: (1, 3, 15, 200)
# dt_short rmse mean: 8.12248706817627
# dt_short rmse std: 1.3227513615493296
# dt_short average R^2 score: 0.6439119219779968
# dt_short R^2 score std: 0.1087130203670553
#
# param: (1, 3, 20, 100)
# dt_short rmse mean: 8.125063037872314
# dt_short rmse std: 1.319962386305621
# dt_short average R^2 score: 0.6437291145324707
# dt_short R^2 score std: 0.10847546946727742
#
# param: (1, 3, 20, 200)
# dt_short rmse mean: 8.125297927856446
# dt_short rmse std: 1.3215633775818785
# dt_short average R^2 score: 0.6436812043190002
# dt_short R^2 score std: 0.1086251503309456
#
# param: (1, 5, 5, 100)
# dt_short rmse mean: 8.068513011932373
# dt_short rmse std: 1.2745465181344968
# dt_short average R^2 score: 0.6492697119712829
# dt_short R^2 score std: 0.10453188031131809
#
# param: (1, 5, 5, 200)
# dt_short rmse mean: 8.063365840911866
# dt_short rmse std: 1.3080984589495728
# dt_short average R^2 score: 0.6492923736572266
# dt_short R^2 score std: 0.10734552569857111
#
# param: (1, 5, 10, 100)
# dt_short rmse mean: 8.110423469543457
# dt_short rmse std: 1.3003005819656819
# dt_short average R^2 score: 0.6452917575836181
# dt_short R^2 score std: 0.10655345966517765
#
# param: (1, 5, 10, 200)
# dt_short rmse mean: 8.12578525543213
# dt_short rmse std: 1.310649903831013
# dt_short average R^2 score: 0.6438096046447754
# dt_short R^2 score std: 0.10790906068021358
#
# param: (1, 5, 15, 100)
# dt_short rmse mean: 8.114453983306884
# dt_short rmse std: 1.3221034018253073
# dt_short average R^2 score: 0.6446289658546448
# dt_short R^2 score std: 0.10863008261984931
#
# param: (1, 5, 15, 200)
# dt_short rmse mean: 8.119150829315185
# dt_short rmse std: 1.3236189478095277
# dt_short average R^2 score: 0.6441833138465881
# dt_short R^2 score std: 0.10889500042182704
#
# param: (1, 5, 20, 100)
# dt_short rmse mean: 8.110684013366699
# dt_short rmse std: 1.3223411293029477
# dt_short average R^2 score: 0.6449411273002624
# dt_short R^2 score std: 0.10861471403965421
#
# param: (1, 5, 20, 200)
# dt_short rmse mean: 8.115643119812011
# dt_short rmse std: 1.3221985890121921
# dt_short average R^2 score: 0.6444993734359741
# dt_short R^2 score std: 0.10868231844150389
#
# param: (1, 10, 5, 100)
# dt_short rmse mean: 8.06825122833252
# dt_short rmse std: 1.270521867021488
# dt_short average R^2 score: 0.6493988633155823
# dt_short R^2 score std: 0.10410134884346683
#
# param: (1, 10, 5, 200)
# dt_short rmse mean: 8.062164783477783
# dt_short rmse std: 1.2943332563581118
# dt_short average R^2 score: 0.6495859265327454
# dt_short R^2 score std: 0.10628660350168602
#
# param: (1, 10, 10, 100)
# dt_short rmse mean: 8.092350196838378
# dt_short rmse std: 1.2989447329589492
# dt_short average R^2 score: 0.6469072699546814
# dt_short R^2 score std: 0.10606796077888377
#
# param: (1, 10, 10, 200)
# dt_short rmse mean: 8.102806854248048
# dt_short rmse std: 1.3087896150537406
# dt_short average R^2 score: 0.645831310749054
# dt_short R^2 score std: 0.10732486877210898
#
# param: (1, 10, 15, 100)
# dt_short rmse mean: 8.119240665435791
# dt_short rmse std: 1.3214776825437677
# dt_short average R^2 score: 0.6443058609962463
# dt_short R^2 score std: 0.10859496765411099
#
# param: (1, 10, 15, 200)
# dt_short rmse mean: 8.122564315795898
# dt_short rmse std: 1.3207399624690048
# dt_short average R^2 score: 0.6439937353134155
# dt_short R^2 score std: 0.10864381332134451
#
# param: (1, 10, 20, 100)
# dt_short rmse mean: 8.120688533782959
# dt_short rmse std: 1.321639520103773
# dt_short average R^2 score: 0.6441694140434265
# dt_short R^2 score std: 0.10864858965549921
#
# param: (1, 10, 20, 200)
# dt_short rmse mean: 8.124528217315675
# dt_short rmse std: 1.3221944596976372
# dt_short average R^2 score: 0.6438091278076172
# dt_short R^2 score std: 0.10876867075395594
#
# param: (1, 20, 5, 100)
# dt_short rmse mean: 8.054335784912109
# dt_short rmse std: 1.248983512523555
# dt_short average R^2 score: 0.6507596015930176
# dt_short R^2 score std: 0.1022213693053259
#
# param: (1, 20, 5, 200)
# dt_short rmse mean: 8.048110485076904
# dt_short rmse std: 1.2733165044741896
# dt_short average R^2 score: 0.651000189781189
# dt_short R^2 score std: 0.10447300611795857
#
# param: (1, 20, 10, 100)
# dt_short rmse mean: 8.08284969329834
# dt_short rmse std: 1.2823968445969904
# dt_short average R^2 score: 0.6479109525680542
# dt_short R^2 score std: 0.10487309046077832
#
# param: (1, 20, 10, 200)
# dt_short rmse mean: 8.100751304626465
# dt_short rmse std: 1.2934986601104912
# dt_short average R^2 score: 0.6462286829948425
# dt_short R^2 score std: 0.10627422921585414
#
# param: (1, 20, 15, 100)
# dt_short rmse mean: 8.102190685272216
# dt_short rmse std: 1.3052350813159985
# dt_short average R^2 score: 0.6460463047027588
# dt_short R^2 score std: 0.107114359310779
#
# param: (1, 20, 15, 200)
# dt_short rmse mean: 8.110726451873779
# dt_short rmse std: 1.3043568231009641
# dt_short average R^2 score: 0.6452912092208862
# dt_short R^2 score std: 0.10723217979879536
#
# param: (1, 20, 20, 100)
# dt_short rmse mean: 8.098458957672118
# dt_short rmse std: 1.293539555283212
# dt_short average R^2 score: 0.6464584589004516
# dt_short R^2 score std: 0.10606266136829086
#
# param: (1, 20, 20, 200)
# dt_short rmse mean: 8.105262756347656
# dt_short rmse std: 1.3037477380433045
# dt_short average R^2 score: 0.6457114815711975
# dt_short R^2 score std: 0.10707975352047308
#
# param: (3, 0, 5, 100)
# dt_short rmse mean: 8.084475231170654
# dt_short rmse std: 1.253987179094859
# dt_short average R^2 score: 0.648185133934021
# dt_short R^2 score std: 0.10309520902203137
#
# param: (3, 0, 5, 200)
# dt_short rmse mean: 8.077929973602295
# dt_short rmse std: 1.2554243002736576
# dt_short average R^2 score: 0.6487837314605713
# dt_short R^2 score std: 0.10299925249364342
#
# param: (3, 0, 10, 100)
# dt_short rmse mean: 8.107870864868165
# dt_short rmse std: 1.3079631436132144
# dt_short average R^2 score: 0.6453729033470154
# dt_short R^2 score std: 0.10704636658433324
#
# param: (3, 0, 10, 200)
# dt_short rmse mean: 8.120034980773926
# dt_short rmse std: 1.3237151376863308
# dt_short average R^2 score: 0.6441166043281555
# dt_short R^2 score std: 0.10875983371108112
#
# param: (3, 0, 15, 100)
# dt_short rmse mean: 8.122940921783448
# dt_short rmse std: 1.327342742033073
# dt_short average R^2 score: 0.6438063979148865
# dt_short R^2 score std: 0.10913275910210411
#
# param: (3, 0, 15, 200)
# dt_short rmse mean: 8.124271869659424
# dt_short rmse std: 1.3272112052735374
# dt_short average R^2 score: 0.6436888575553894
# dt_short R^2 score std: 0.10913860966246526
#
# param: (3, 0, 20, 100)
# dt_short rmse mean: 8.124096870422363
# dt_short rmse std: 1.3273382814261543
# dt_short average R^2 score: 0.6437034964561462
# dt_short R^2 score std: 0.10914698888650769
#
# param: (3, 0, 20, 200)
# dt_short rmse mean: 8.124315643310547
# dt_short rmse std: 1.3272371002495853
# dt_short average R^2 score: 0.6436846852302551
# dt_short R^2 score std: 0.10914104573715894
#
# param: (3, 1, 5, 100)
# dt_short rmse mean: 8.060252571105957
# dt_short rmse std: 1.2562785600530166
# dt_short average R^2 score: 0.6502159357070922
# dt_short R^2 score std: 0.10292422557725
#
# param: (3, 1, 5, 200)
# dt_short rmse mean: 8.060499477386475
# dt_short rmse std: 1.294320855084097
# dt_short average R^2 score: 0.6497048139572144
# dt_short R^2 score std: 0.10601847161587863
#
# param: (3, 1, 10, 100)
# dt_short rmse mean: 8.108437061309814
# dt_short rmse std: 1.316307430015891
# dt_short average R^2 score: 0.6452144742012024
# dt_short R^2 score std: 0.10767341025598125
#
# param: (3, 1, 10, 200)
# dt_short rmse mean: 8.115618133544922
# dt_short rmse std: 1.3231799502553265
# dt_short average R^2 score: 0.6445122957229614
# dt_short R^2 score std: 0.1086305633265183
#
# param: (3, 1, 15, 100)
# dt_short rmse mean: 8.118704795837402
# dt_short rmse std: 1.3251581421421101
# dt_short average R^2 score: 0.6442070126533508
# dt_short R^2 score std: 0.1089064956873108
#
# param: (3, 1, 15, 200)
# dt_short rmse mean: 8.12289113998413
# dt_short rmse std: 1.3261701658763985
# dt_short average R^2 score: 0.643825912475586
# dt_short R^2 score std: 0.10905650171313494
#
# param: (3, 1, 20, 100)
# dt_short rmse mean: 8.121201038360596
# dt_short rmse std: 1.3269425167059319
# dt_short average R^2 score: 0.6439686059951782
# dt_short R^2 score std: 0.10907999657981361
#
# param: (3, 1, 20, 200)
# dt_short rmse mean: 8.124250316619873
# dt_short rmse std: 1.326740516835657
# dt_short average R^2 score: 0.6437007308006286
# dt_short R^2 score std: 0.10910946538289282
#
# param: (3, 3, 5, 100)
# dt_short rmse mean: 8.052752780914307
# dt_short rmse std: 1.2499179148226818
# dt_short average R^2 score: 0.650934386253357
# dt_short R^2 score std: 0.10186229600756706
#
# param: (3, 3, 5, 200)
# dt_short rmse mean: 8.048519802093505
# dt_short rmse std: 1.2627529535839603
# dt_short average R^2 score: 0.6511888146400452
# dt_short R^2 score std: 0.10285604050733384
#
# param: (3, 3, 10, 100)
# dt_short rmse mean: 8.09960241317749
# dt_short rmse std: 1.3050324085436797
# dt_short average R^2 score: 0.6461301565170288
# dt_short R^2 score std: 0.10711339267513245
#
# param: (3, 3, 10, 200)
# dt_short rmse mean: 8.110915565490723
# dt_short rmse std: 1.310622899126911
# dt_short average R^2 score: 0.6450579285621643
# dt_short R^2 score std: 0.1077940155545178
#
# param: (3, 3, 15, 100)
# dt_short rmse mean: 8.120192813873292
# dt_short rmse std: 1.32153329994695
# dt_short average R^2 score: 0.6441417574882508
# dt_short R^2 score std: 0.10873501477014058
#
# param: (3, 3, 15, 200)
# dt_short rmse mean: 8.121985530853271
# dt_short rmse std: 1.321336459242481
# dt_short average R^2 score: 0.6439743876457215
# dt_short R^2 score std: 0.10870882182531676
#
# param: (3, 3, 20, 100)
# dt_short rmse mean: 8.123946857452392
# dt_short rmse std: 1.3269513091722798
# dt_short average R^2 score: 0.6437592387199402
# dt_short R^2 score std: 0.1091769143604157
#
# param: (3, 3, 20, 200)
# dt_short rmse mean: 8.12371072769165
# dt_short rmse std: 1.3262585114263334
# dt_short average R^2 score: 0.6437718749046326
# dt_short R^2 score std: 0.1091080649217343
#
# param: (3, 5, 5, 100)
# dt_short rmse mean: 8.077588748931884
# dt_short rmse std: 1.275781052592392
# dt_short average R^2 score: 0.6485068917274475
# dt_short R^2 score std: 0.10498270116621514
#
# param: (3, 5, 5, 200)
# dt_short rmse mean: 8.078473758697509
# dt_short rmse std: 1.281949237648622
# dt_short average R^2 score: 0.6483952045440674
# dt_short R^2 score std: 0.10542984245402913
#
# param: (3, 5, 10, 100)
# dt_short rmse mean: 8.089954662322999
# dt_short rmse std: 1.313321238980669
# dt_short average R^2 score: 0.6468762755393982
# dt_short R^2 score std: 0.10771457048790117
#
# param: (3, 5, 10, 200)
# dt_short rmse mean: 8.109801387786865
# dt_short rmse std: 1.322054058952876
# dt_short average R^2 score: 0.645049798488617
# dt_short R^2 score std: 0.1088328542307436
#
# param: (3, 5, 15, 100)
# dt_short rmse mean: 8.11564302444458
# dt_short rmse std: 1.3249984313987624
# dt_short average R^2 score: 0.6444971442222596
# dt_short R^2 score std: 0.10905978196080421
#
# param: (3, 5, 15, 200)
# dt_short rmse mean: 8.12096872329712
# dt_short rmse std: 1.3281602621386606
# dt_short average R^2 score: 0.6439877152442932
# dt_short R^2 score std: 0.1093792667780501
#
# param: (3, 5, 20, 100)
# dt_short rmse mean: 8.117920112609863
# dt_short rmse std: 1.3219185224766992
# dt_short average R^2 score: 0.6443295836448669
# dt_short R^2 score std: 0.10884265893299772
#
# param: (3, 5, 20, 200)
# dt_short rmse mean: 8.12007417678833
# dt_short rmse std: 1.3225311983631074
# dt_short average R^2 score: 0.6441213369369507
# dt_short R^2 score std: 0.10892615445828076
#
# param: (3, 10, 5, 100)
# dt_short rmse mean: 8.072581672668457
# dt_short rmse std: 1.2451372619291203
# dt_short average R^2 score: 0.6492859482765198
# dt_short R^2 score std: 0.10285690961687251
#
# param: (3, 10, 5, 200)
# dt_short rmse mean: 8.063470840454102
# dt_short rmse std: 1.2606625418588226
# dt_short average R^2 score: 0.6498270273208618
# dt_short R^2 score std: 0.10392352022107594
#
# param: (3, 10, 10, 100)
# dt_short rmse mean: 8.085091018676758
# dt_short rmse std: 1.3002382921797497
# dt_short average R^2 score: 0.6475430488586426
# dt_short R^2 score std: 0.10623831793115869
#
# param: (3, 10, 10, 200)
# dt_short rmse mean: 8.099415588378907
# dt_short rmse std: 1.3149369042793413
# dt_short average R^2 score: 0.6461041212081909
# dt_short R^2 score std: 0.1079822386456941
#
# param: (3, 10, 15, 100)
# dt_short rmse mean: 8.112650108337402
# dt_short rmse std: 1.3104600165040017
# dt_short average R^2 score: 0.6450080871582031
# dt_short R^2 score std: 0.10753005203339966
#
# param: (3, 10, 15, 200)
# dt_short rmse mean: 8.1169939994812
# dt_short rmse std: 1.3133760219981157
# dt_short average R^2 score: 0.6445645928382874
# dt_short R^2 score std: 0.10788640158127819
#
# param: (3, 10, 20, 100)
# dt_short rmse mean: 8.107871627807617
# dt_short rmse std: 1.3205169182576066
# dt_short average R^2 score: 0.6452678680419922
# dt_short R^2 score std: 0.10847766078688549
#
# param: (3, 10, 20, 200)
# dt_short rmse mean: 8.110980892181397
# dt_short rmse std: 1.32605185942066
# dt_short average R^2 score: 0.6449073791503906
# dt_short R^2 score std: 0.10905806954419311
#
# param: (3, 20, 5, 100)
# dt_short rmse mean: 8.052665424346923
# dt_short rmse std: 1.2251985327790356
# dt_short average R^2 score: 0.6511024713516236
# dt_short R^2 score std: 0.1007160735789143
#
# param: (3, 20, 5, 200)
# dt_short rmse mean: 8.028910160064697
# dt_short rmse std: 1.2443268942980277
# dt_short average R^2 score: 0.653055727481842
# dt_short R^2 score std: 0.10187104219365756
#
# param: (3, 20, 10, 100)
# dt_short rmse mean: 8.080088329315185
# dt_short rmse std: 1.283640603997763
# dt_short average R^2 score: 0.6481969594955445
# dt_short R^2 score std: 0.10467292626212583
#
# param: (3, 20, 10, 200)
# dt_short rmse mean: 8.08145637512207
# dt_short rmse std: 1.3139518422121332
# dt_short average R^2 score: 0.6476365089416504
# dt_short R^2 score std: 0.1076064316820623
#
# param: (3, 20, 15, 100)
# dt_short rmse mean: 8.108789348602295
# dt_short rmse std: 1.2984006649694773
# dt_short average R^2 score: 0.6455975294113159
# dt_short R^2 score std: 0.1063635662891164
#
# param: (3, 20, 15, 200)
# dt_short rmse mean: 8.110917663574218
# dt_short rmse std: 1.3075354541219708
# dt_short average R^2 score: 0.6452513217926026
# dt_short R^2 score std: 0.10732265715340987
#
# param: (3, 20, 20, 100)
# dt_short rmse mean: 8.104043865203858
# dt_short rmse std: 1.310612076314663
# dt_short average R^2 score: 0.6458043456077576
# dt_short R^2 score std: 0.10752360544375239
#
# param: (3, 20, 20, 200)
# dt_short rmse mean: 8.105698776245116
# dt_short rmse std: 1.3120611573518737
# dt_short average R^2 score: 0.6456210255622864
# dt_short R^2 score std: 0.1077196647518016
#
# param: (5, 0, 5, 100)
# dt_short rmse mean: 8.034741973876953
# dt_short rmse std: 1.2513803199713882
# dt_short average R^2 score: 0.6524475932121276
# dt_short R^2 score std: 0.1026891947647198
#
# param: (5, 0, 5, 200)
# dt_short rmse mean: 8.059750938415528
# dt_short rmse std: 1.2690808008283558
# dt_short average R^2 score: 0.6501938819885253
# dt_short R^2 score std: 0.10410897300255849
#
# param: (5, 0, 10, 100)
# dt_short rmse mean: 8.087034225463867
# dt_short rmse std: 1.3053434862294906
# dt_short average R^2 score: 0.6472171425819397
# dt_short R^2 score std: 0.10660674514576614
#
# param: (5, 0, 10, 200)
# dt_short rmse mean: 8.10915756225586
# dt_short rmse std: 1.3231899350460532
# dt_short average R^2 score: 0.6450915575027466
# dt_short R^2 score std: 0.10856645535158004
#
# param: (5, 0, 15, 100)
# dt_short rmse mean: 8.120834922790527
# dt_short rmse std: 1.3283651584228748
# dt_short average R^2 score: 0.643979299068451
# dt_short R^2 score std: 0.10921902291868105
#
# param: (5, 0, 15, 200)
# dt_short rmse mean: 8.123548221588134
# dt_short rmse std: 1.3276518304874652
# dt_short average R^2 score: 0.6437470436096191
# dt_short R^2 score std: 0.10916526194049452
#
# param: (5, 0, 20, 100)
# dt_short rmse mean: 8.123133850097656
# dt_short rmse std: 1.3277437802247571
# dt_short average R^2 score: 0.6437847137451171
# dt_short R^2 score std: 0.10917438687952934
#
# param: (5, 0, 20, 200)
# dt_short rmse mean: 8.12429666519165
# dt_short rmse std: 1.3272870029001294
# dt_short average R^2 score: 0.643685781955719
# dt_short R^2 score std: 0.10914582702899278
#
# param: (5, 1, 5, 100)
# dt_short rmse mean: 8.053252124786377
# dt_short rmse std: 1.2614526953688165
# dt_short average R^2 score: 0.6507354259490967
# dt_short R^2 score std: 0.10378958532886057
#
# param: (5, 1, 5, 200)
# dt_short rmse mean: 8.04805784225464
# dt_short rmse std: 1.2724557523042064
# dt_short average R^2 score: 0.6510464191436768
# dt_short R^2 score std: 0.104552707558098
#
# param: (5, 1, 10, 100)
# dt_short rmse mean: 8.080283451080323
# dt_short rmse std: 1.3149256177586446
# dt_short average R^2 score: 0.6476584672927856
# dt_short R^2 score std: 0.10715548066282912
#
# param: (5, 1, 10, 200)
# dt_short rmse mean: 8.109230518341064
# dt_short rmse std: 1.3217822699111992
# dt_short average R^2 score: 0.6450793981552124
# dt_short R^2 score std: 0.1084054817286935
#
# param: (5, 1, 15, 100)
# dt_short rmse mean: 8.117738342285156
# dt_short rmse std: 1.3298155796057383
# dt_short average R^2 score: 0.644228196144104
# dt_short R^2 score std: 0.10942270188741332
#
# param: (5, 1, 15, 200)
# dt_short rmse mean: 8.121880626678466
# dt_short rmse std: 1.3284941958992258
# dt_short average R^2 score: 0.6438760995864868
# dt_short R^2 score std: 0.10930837686922183
#
# param: (5, 1, 20, 100)
# dt_short rmse mean: 8.120544338226319
# dt_short rmse std: 1.327701802426566
# dt_short average R^2 score: 0.644017219543457
# dt_short R^2 score std: 0.10916105881541499
#
# param: (5, 1, 20, 200)
# dt_short rmse mean: 8.123123359680175
# dt_short rmse std: 1.3277652970963911
# dt_short average R^2 score: 0.6437847256660462
# dt_short R^2 score std: 0.10920681271969311
#
# param: (5, 3, 5, 100)
# dt_short rmse mean: 8.039033222198487
# dt_short rmse std: 1.2818807846089733
# dt_short average R^2 score: 0.6516277194023132
# dt_short R^2 score std: 0.10487950976260468
#
# param: (5, 3, 5, 200)
# dt_short rmse mean: 8.05038661956787
# dt_short rmse std: 1.275954891963349
# dt_short average R^2 score: 0.6507180213928223
# dt_short R^2 score std: 0.10421813339115386
#
# param: (5, 3, 10, 100)
# dt_short rmse mean: 8.083412265777588
# dt_short rmse std: 1.3011769740465227
# dt_short average R^2 score: 0.647676682472229
# dt_short R^2 score std: 0.10619130136503016
#
# param: (5, 3, 10, 200)
# dt_short rmse mean: 8.099870204925537
# dt_short rmse std: 1.314466847435011
# dt_short average R^2 score: 0.6460557818412781
# dt_short R^2 score std: 0.10775978237306792
#
# param: (5, 3, 15, 100)
# dt_short rmse mean: 8.109186553955078
# dt_short rmse std: 1.3233487283451628
# dt_short average R^2 score: 0.6450591802597045
# dt_short R^2 score std: 0.10880826114045646
#
# param: (5, 3, 15, 200)
# dt_short rmse mean: 8.116785144805908
# dt_short rmse std: 1.3262112568693816
# dt_short average R^2 score: 0.6443527579307556
# dt_short R^2 score std: 0.10913937909312989
#
# param: (5, 3, 20, 100)
# dt_short rmse mean: 8.118482208251953
# dt_short rmse std: 1.330384761657812
# dt_short average R^2 score: 0.6441626191139221
# dt_short R^2 score std: 0.10953904260274594
#
# param: (5, 3, 20, 200)
# dt_short rmse mean: 8.121225166320801
# dt_short rmse std: 1.3288667203784899
# dt_short average R^2 score: 0.6439295291900635
# dt_short R^2 score std: 0.10940644503784182
#
# param: (5, 5, 5, 100)
# dt_short rmse mean: 8.056326293945313
# dt_short rmse std: 1.2569842337310229
# dt_short average R^2 score: 0.6504786014556885
# dt_short R^2 score std: 0.10280648974488397
#
# param: (5, 5, 5, 200)
# dt_short rmse mean: 8.042994785308839
# dt_short rmse std: 1.2872654098097018
# dt_short average R^2 score: 0.6513121843338012
# dt_short R^2 score std: 0.10510497833165698
#
# param: (5, 5, 10, 100)
# dt_short rmse mean: 8.096785736083984
# dt_short rmse std: 1.3134908513963242
# dt_short average R^2 score: 0.6463221549987793
# dt_short R^2 score std: 0.10781089850561984
#
# param: (5, 5, 10, 200)
# dt_short rmse mean: 8.115176391601562
# dt_short rmse std: 1.3170980978739153
# dt_short average R^2 score: 0.6446659803390503
# dt_short R^2 score std: 0.10844611133127374
#
# param: (5, 5, 15, 100)
# dt_short rmse mean: 8.114875984191894
# dt_short rmse std: 1.3232170911605339
# dt_short average R^2 score: 0.6446160316467285
# dt_short R^2 score std: 0.10886628873779339
#
# param: (5, 5, 15, 200)
# dt_short rmse mean: 8.120191478729248
# dt_short rmse std: 1.3278977429098102
# dt_short average R^2 score: 0.6440617322921753
# dt_short R^2 score std: 0.10933878627474013
#
# param: (5, 5, 20, 100)
# dt_short rmse mean: 8.11049747467041
# dt_short rmse std: 1.323357493092514
# dt_short average R^2 score: 0.6449626684188843
# dt_short R^2 score std: 0.10878172691119471
#
# param: (5, 5, 20, 200)
# dt_short rmse mean: 8.112880516052247
# dt_short rmse std: 1.3239306134516113
# dt_short average R^2 score: 0.6447273135185242
# dt_short R^2 score std: 0.10884913830947442
#
# param: (5, 10, 5, 100)
# dt_short rmse mean: 8.041423225402832
# dt_short rmse std: 1.2735154216107591
# dt_short average R^2 score: 0.651547122001648
# dt_short R^2 score std: 0.10429968851655624
#
# param: (5, 10, 5, 200)
# dt_short rmse mean: 8.039626789093017
# dt_short rmse std: 1.2996655422800873
# dt_short average R^2 score: 0.6513506889343261
# dt_short R^2 score std: 0.10665458981228845
#
# param: (5, 10, 10, 100)
# dt_short rmse mean: 8.087540626525879
# dt_short rmse std: 1.3034058957124897
# dt_short average R^2 score: 0.6472645401954651
# dt_short R^2 score std: 0.10673468131680215
#
# param: (5, 10, 10, 200)
# dt_short rmse mean: 8.112825298309327
# dt_short rmse std: 1.3208221312441724
# dt_short average R^2 score: 0.6448451757431031
# dt_short R^2 score std: 0.10866359591402489
#
# param: (5, 10, 15, 100)
# dt_short rmse mean: 8.095091915130615
# dt_short rmse std: 1.3220298874448038
# dt_short average R^2 score: 0.6463462114334106
# dt_short R^2 score std: 0.10846215059947595
#
# param: (5, 10, 15, 200)
# dt_short rmse mean: 8.102767086029052
# dt_short rmse std: 1.325121436239415
# dt_short average R^2 score: 0.645614218711853
# dt_short R^2 score std: 0.10886199096070516
#
# param: (5, 10, 20, 100)
# dt_short rmse mean: 8.10015172958374
# dt_short rmse std: 1.316985901876448
# dt_short average R^2 score: 0.6459856152534484
# dt_short R^2 score std: 0.10820819095759453
#
# param: (5, 10, 20, 200)
# dt_short rmse mean: 8.107720470428466
# dt_short rmse std: 1.3224554730286726
# dt_short average R^2 score: 0.6452420473098754
# dt_short R^2 score std: 0.10878193193865722
#
# param: (5, 20, 5, 100)
# dt_short rmse mean: 8.043629169464111
# dt_short rmse std: 1.239016511326843
# dt_short average R^2 score: 0.6517529606819152
# dt_short R^2 score std: 0.10140459281605851
#
# param: (5, 20, 5, 200)
# dt_short rmse mean: 8.03851842880249
# dt_short rmse std: 1.2567751605060336
# dt_short average R^2 score: 0.6520208597183228
# dt_short R^2 score std: 0.102522075258297
#
# param: (5, 20, 10, 100)
# dt_short rmse mean: 8.078983306884766
# dt_short rmse std: 1.285696507084499
# dt_short average R^2 score: 0.64824880361557
# dt_short R^2 score std: 0.10542059732336831
#
# param: (5, 20, 10, 200)
# dt_short rmse mean: 8.09791965484619
# dt_short rmse std: 1.3013880439202392
# dt_short average R^2 score: 0.6463851690292358
# dt_short R^2 score std: 0.10715371628480033
#
# param: (5, 20, 15, 100)
# dt_short rmse mean: 8.103898620605468
# dt_short rmse std: 1.3085098733305551
# dt_short average R^2 score: 0.6457703828811645
# dt_short R^2 score std: 0.10777024980681935
#
# param: (5, 20, 15, 200)
# dt_short rmse mean: 8.11100378036499
# dt_short rmse std: 1.311797967664944
# dt_short average R^2 score: 0.6450811147689819
# dt_short R^2 score std: 0.10833881251752728
#
# param: (5, 20, 20, 100)
# dt_short rmse mean: 8.101915073394775
# dt_short rmse std: 1.314908072515175
# dt_short average R^2 score: 0.6458643078804016
# dt_short R^2 score std: 0.10825616788255532
#
# param: (5, 20, 20, 200)
# dt_short rmse mean: 8.110400104522705
# dt_short rmse std: 1.3183450709787214
# dt_short average R^2 score: 0.6450721383094787
# dt_short R^2 score std: 0.10881412777701545
#
# param: (10, 0, 5, 100)
# dt_short rmse mean: 8.083645248413086
# dt_short rmse std: 1.2462506048605269
# dt_short average R^2 score: 0.6482792019844055
# dt_short R^2 score std: 0.10191984611154903
#
# param: (10, 0, 5, 200)
# dt_short rmse mean: 8.079610443115234
# dt_short rmse std: 1.2533377985946723
# dt_short average R^2 score: 0.6485988855361938
# dt_short R^2 score std: 0.10246414554498391
#
# param: (10, 0, 10, 100)
# dt_short rmse mean: 8.089041328430175
# dt_short rmse std: 1.3119324692039613
# dt_short average R^2 score: 0.6469474673271179
# dt_short R^2 score std: 0.10763459155541036
#
# param: (10, 0, 10, 200)
# dt_short rmse mean: 8.108677673339844
# dt_short rmse std: 1.3199081854770205
# dt_short average R^2 score: 0.6451786637306214
# dt_short R^2 score std: 0.1085098961446834
#
# param: (10, 0, 15, 100)
# dt_short rmse mean: 8.112512493133545
# dt_short rmse std: 1.3308696798527022
# dt_short average R^2 score: 0.644690728187561
# dt_short R^2 score std: 0.10934980559506935
#
# param: (10, 0, 15, 200)
# dt_short rmse mean: 8.120189380645751
# dt_short rmse std: 1.3294149670624225
# dt_short average R^2 score: 0.6440245747566223
# dt_short R^2 score std: 0.10926873249853489
#
# param: (10, 0, 20, 100)
# dt_short rmse mean: 8.118708038330078
# dt_short rmse std: 1.329342846076708
# dt_short average R^2 score: 0.6441607236862182
# dt_short R^2 score std: 0.10927307282508295
#
# param: (10, 0, 20, 200)
# dt_short rmse mean: 8.123958587646484
# dt_short rmse std: 1.327435423947406
# dt_short average R^2 score: 0.6437143802642822
# dt_short R^2 score std: 0.10915689671929737
#
# param: (10, 1, 5, 100)
# dt_short rmse mean: 8.06278190612793
# dt_short rmse std: 1.2561775662575045
# dt_short average R^2 score: 0.6498594045639038
# dt_short R^2 score std: 0.10345453769552847
#
# param: (10, 1, 5, 200)
# dt_short rmse mean: 8.048122882843018
# dt_short rmse std: 1.2618523299185007
# dt_short average R^2 score: 0.6511301159858703
# dt_short R^2 score std: 0.10362621045323546
#
# param: (10, 1, 10, 100)
# dt_short rmse mean: 8.095271682739257
# dt_short rmse std: 1.30568623792855
# dt_short average R^2 score: 0.6464489817619323
# dt_short R^2 score std: 0.10707955054202965
#
# param: (10, 1, 10, 200)
# dt_short rmse mean: 8.102336120605468
# dt_short rmse std: 1.3064055931941974
# dt_short average R^2 score: 0.6458693861961364
# dt_short R^2 score std: 0.10704640857097232
#
# param: (10, 1, 15, 100)
# dt_short rmse mean: 8.114406204223632
# dt_short rmse std: 1.328142672527274
# dt_short average R^2 score: 0.6445637226104737
# dt_short R^2 score std: 0.1092288345539426
#
# param: (10, 1, 15, 200)
# dt_short rmse mean: 8.120124912261963
# dt_short rmse std: 1.3281500968534314
# dt_short average R^2 score: 0.6440559983253479
# dt_short R^2 score std: 0.10922396454758743
#
# param: (10, 1, 20, 100)
# dt_short rmse mean: 8.118450832366943
# dt_short rmse std: 1.3297396371058525
# dt_short average R^2 score: 0.6441942811012268
# dt_short R^2 score std: 0.10935418253510237
#
# param: (10, 1, 20, 200)
# dt_short rmse mean: 8.123678016662598
# dt_short rmse std: 1.3289554446298617
# dt_short average R^2 score: 0.6437301278114319
# dt_short R^2 score std: 0.10932901881169255
#
# param: (10, 3, 5, 100)
# dt_short rmse mean: 8.044368362426757
# dt_short rmse std: 1.2585406186288486
# dt_short average R^2 score: 0.6513690948486328
# dt_short R^2 score std: 0.10321027188692435
#
# param: (10, 3, 5, 200)
# dt_short rmse mean: 8.053281688690186
# dt_short rmse std: 1.2966078391000098
# dt_short average R^2 score: 0.6503040432929993
# dt_short R^2 score std: 0.10605679548423128
#
# param: (10, 3, 10, 100)
# dt_short rmse mean: 8.096562004089355
# dt_short rmse std: 1.3032923532391223
# dt_short average R^2 score: 0.6463743805885315
# dt_short R^2 score std: 0.10663356817269579
#
# param: (10, 3, 10, 200)
# dt_short rmse mean: 8.111799430847167
# dt_short rmse std: 1.3152491069177932
# dt_short average R^2 score: 0.6449453473091126
# dt_short R^2 score std: 0.10807597906368759
#
# param: (10, 3, 15, 100)
# dt_short rmse mean: 8.106842422485352
# dt_short rmse std: 1.323028978981944
# dt_short average R^2 score: 0.6453028202056885
# dt_short R^2 score std: 0.10864119921325258
#
# param: (10, 3, 15, 200)
# dt_short rmse mean: 8.11706085205078
# dt_short rmse std: 1.3238962031672046
# dt_short average R^2 score: 0.6443773746490479
# dt_short R^2 score std: 0.10883893466178735
#
# param: (10, 3, 20, 100)
# dt_short rmse mean: 8.108349514007568
# dt_short rmse std: 1.325523691767219
# dt_short average R^2 score: 0.6451357960700989
# dt_short R^2 score std: 0.10889511306732932
#
# param: (10, 3, 20, 200)
# dt_short rmse mean: 8.11732177734375
# dt_short rmse std: 1.3265878513561706
# dt_short average R^2 score: 0.644321060180664
# dt_short R^2 score std: 0.10907582211484866
#
# param: (10, 5, 5, 100)
# dt_short rmse mean: 8.0707275390625
# dt_short rmse std: 1.2588174320118832
# dt_short average R^2 score: 0.649272906780243
# dt_short R^2 score std: 0.10310035069845311
#
# param: (10, 5, 5, 200)
# dt_short rmse mean: 8.051539421081543
# dt_short rmse std: 1.276533490088081
# dt_short average R^2 score: 0.6507676005363464
# dt_short R^2 score std: 0.10406813161859947
#
# param: (10, 5, 10, 100)
# dt_short rmse mean: 8.080123329162598
# dt_short rmse std: 1.2814152492053557
# dt_short average R^2 score: 0.6481451869010926
# dt_short R^2 score std: 0.10482291955412351
#
# param: (10, 5, 10, 200)
# dt_short rmse mean: 8.104601860046387
# dt_short rmse std: 1.300648051700848
# dt_short average R^2 score: 0.6457786321640014
# dt_short R^2 score std: 0.10697334116746941
#
# param: (10, 5, 15, 100)
# dt_short rmse mean: 8.100713539123536
# dt_short rmse std: 1.3201564288869467
# dt_short average R^2 score: 0.6458555340766907
# dt_short R^2 score std: 0.10842180828817233
#
# param: (10, 5, 15, 200)
# dt_short rmse mean: 8.108847618103027
# dt_short rmse std: 1.3182460434083303
# dt_short average R^2 score: 0.6451594829559326
# dt_short R^2 score std: 0.1082409097511872
#
# param: (10, 5, 20, 100)
# dt_short rmse mean: 8.102829265594483
# dt_short rmse std: 1.319752940462048
# dt_short average R^2 score: 0.6456765294075012
# dt_short R^2 score std: 0.10833150632131987
#
# param: (10, 5, 20, 200)
# dt_short rmse mean: 8.112500762939453
# dt_short rmse std: 1.3216277800698013
# dt_short average R^2 score: 0.6447916984558105
# dt_short R^2 score std: 0.10859550403199651
#
# param: (10, 10, 5, 100)
# dt_short rmse mean: 8.077903079986573
# dt_short rmse std: 1.2453359000493733
# dt_short average R^2 score: 0.6487991094589234
# dt_short R^2 score std: 0.10190850104443339
#
# param: (10, 10, 5, 200)
# dt_short rmse mean: 8.077069568634034
# dt_short rmse std: 1.2607957978271875
# dt_short average R^2 score: 0.6486300587654114
# dt_short R^2 score std: 0.10342661881337667
#
# param: (10, 10, 10, 100)
# dt_short rmse mean: 8.068827056884766
# dt_short rmse std: 1.262641091720139
# dt_short average R^2 score: 0.6493908643722535
# dt_short R^2 score std: 0.10303701205637728
#
# param: (10, 10, 10, 200)
# dt_short rmse mean: 8.095617771148682
# dt_short rmse std: 1.2926305342767412
# dt_short average R^2 score: 0.6467007637023926
# dt_short R^2 score std: 0.1062238479696065
#
# param: (10, 10, 15, 100)
# dt_short rmse mean: 8.081323051452637
# dt_short rmse std: 1.3089908375372743
# dt_short average R^2 score: 0.647663128376007
# dt_short R^2 score std: 0.10743780996119301
#
# param: (10, 10, 15, 200)
# dt_short rmse mean: 8.099326705932617
# dt_short rmse std: 1.3166254223906122
# dt_short average R^2 score: 0.6459951877593995
# dt_short R^2 score std: 0.10834456216892964
#
# param: (10, 10, 20, 100)
# dt_short rmse mean: 8.082448387145996
# dt_short rmse std: 1.3060703549748367
# dt_short average R^2 score: 0.6476096630096435
# dt_short R^2 score std: 0.10714132905319748
#
# param: (10, 10, 20, 200)
# dt_short rmse mean: 8.096201038360595
# dt_short rmse std: 1.3125394839390223
# dt_short average R^2 score: 0.6463210582733154
# dt_short R^2 score std: 0.10787555188018387
#
# param: (10, 20, 5, 100)
# dt_short rmse mean: 8.062116336822509
# dt_short rmse std: 1.215168546632785
# dt_short average R^2 score: 0.6503839015960693
# dt_short R^2 score std: 0.09890876194469177
#
# param: (10, 20, 5, 200)
# dt_short rmse mean: 8.07323694229126
# dt_short rmse std: 1.225603024967194
# dt_short average R^2 score: 0.6493301510810852
# dt_short R^2 score std: 0.10016385855812199
#
# param: (10, 20, 10, 100)
# dt_short rmse mean: 8.049455070495606
# dt_short rmse std: 1.3048254181436678
# dt_short average R^2 score: 0.6505514502525329
# dt_short R^2 score std: 0.10703018688234021
#
# param: (10, 20, 10, 200)
# dt_short rmse mean: 8.069880390167237
# dt_short rmse std: 1.325708986844334
# dt_short average R^2 score: 0.648480749130249
# dt_short R^2 score std: 0.10925733176190329
#
# param: (10, 20, 15, 100)
# dt_short rmse mean: 8.080045032501221
# dt_short rmse std: 1.32392915371046
# dt_short average R^2 score: 0.6476635098457336
# dt_short R^2 score std: 0.10903372703944852
#
# param: (10, 20, 15, 200)
# dt_short rmse mean: 8.09838399887085
# dt_short rmse std: 1.3229938955651335
# dt_short average R^2 score: 0.6460795879364014
# dt_short R^2 score std: 0.10931929528022626
#
# param: (10, 20, 20, 100)
# dt_short rmse mean: 8.078681755065919
# dt_short rmse std: 1.3197017519532743
# dt_short average R^2 score: 0.6478213191032409
# dt_short R^2 score std: 0.10859192876188542
#
# param: (10, 20, 20, 200)
# dt_short rmse mean: 8.091544437408448
# dt_short rmse std: 1.3133079951915039
# dt_short average R^2 score: 0.6467602372169494
# dt_short R^2 score std: 0.10828785429658429
#
# param: (20, 0, 5, 100)
# dt_short rmse mean: 8.055887126922608
# dt_short rmse std: 1.245414315401948
# dt_short average R^2 score: 0.6508105278015137
# dt_short R^2 score std: 0.10097858134680725
#
# param: (20, 0, 5, 200)
# dt_short rmse mean: 8.043435382843018
# dt_short rmse std: 1.2859652917172826
# dt_short average R^2 score: 0.6513748884201049
# dt_short R^2 score std: 0.10438530697541648
#
# param: (20, 0, 10, 100)
# dt_short rmse mean: 8.068979835510254
# dt_short rmse std: 1.2963665476869968
# dt_short average R^2 score: 0.6489623785018921
# dt_short R^2 score std: 0.10566584443833764
#
# param: (20, 0, 10, 200)
# dt_short rmse mean: 8.088192653656005
# dt_short rmse std: 1.31943902610052
# dt_short average R^2 score: 0.6469892024993896
# dt_short R^2 score std: 0.10818500815261659
#
# param: (20, 0, 15, 100)
# dt_short rmse mean: 8.108542251586915
# dt_short rmse std: 1.332075901005347
# dt_short average R^2 score: 0.6450303196907043
# dt_short R^2 score std: 0.10940277414835933
#
# param: (20, 0, 15, 200)
# dt_short rmse mean: 8.11877965927124
# dt_short rmse std: 1.3282644734734221
# dt_short average R^2 score: 0.6441726088523865
# dt_short R^2 score std: 0.109182717126421
#
# param: (20, 0, 20, 100)
# dt_short rmse mean: 8.11146650314331
# dt_short rmse std: 1.3338609279192295
# dt_short average R^2 score: 0.6447542905807495
# dt_short R^2 score std: 0.10961049796717237
#
# param: (20, 0, 20, 200)
# dt_short rmse mean: 8.123520851135254
# dt_short rmse std: 1.3292538775761202
# dt_short average R^2 score: 0.6437369585037231
# dt_short R^2 score std: 0.10932494337125877
#
# param: (20, 1, 5, 100)
# dt_short rmse mean: 8.044293880462646
# dt_short rmse std: 1.2173341963369766
# dt_short average R^2 score: 0.6519380569458008
# dt_short R^2 score std: 0.09892376437467171
#
# param: (20, 1, 5, 200)
# dt_short rmse mean: 8.055625534057617
# dt_short rmse std: 1.2300428496312594
# dt_short average R^2 score: 0.6508520245552063
# dt_short R^2 score std: 0.10031479258614742
#
# param: (20, 1, 10, 100)
# dt_short rmse mean: 8.064760494232178
# dt_short rmse std: 1.285298912600327
# dt_short average R^2 score: 0.6494701504707336
# dt_short R^2 score std: 0.10474338966032937
#
# param: (20, 1, 10, 200)
# dt_short rmse mean: 8.088522624969482
# dt_short rmse std: 1.2995963431214796
# dt_short average R^2 score: 0.6471967816352844
# dt_short R^2 score std: 0.10660290162364283
#
# param: (20, 1, 15, 100)
# dt_short rmse mean: 8.103925037384034
# dt_short rmse std: 1.3287390493459619
# dt_short average R^2 score: 0.6454815626144409
# dt_short R^2 score std: 0.10906154777482012
#
# param: (20, 1, 15, 200)
# dt_short rmse mean: 8.115357685089112
# dt_short rmse std: 1.3262453255490878
# dt_short average R^2 score: 0.6445065259933471
# dt_short R^2 score std: 0.10897557294842308
#
# param: (20, 1, 20, 100)
# dt_short rmse mean: 8.107632064819336
# dt_short rmse std: 1.329970554585305
# dt_short average R^2 score: 0.6451499700546265
# dt_short R^2 score std: 0.1091690009279406
#
# param: (20, 1, 20, 200)
# dt_short rmse mean: 8.119176578521728
# dt_short rmse std: 1.327477048970419
# dt_short average R^2 score: 0.6441410183906555
# dt_short R^2 score std: 0.10910894579821244
#
# param: (20, 3, 5, 100)
# dt_short rmse mean: 8.049508476257325
# dt_short rmse std: 1.2536149855280536
# dt_short average R^2 score: 0.6511109352111817
# dt_short R^2 score std: 0.10219193916571108
#
# param: (20, 3, 5, 200)
# dt_short rmse mean: 8.068363761901855
# dt_short rmse std: 1.273833104116808
# dt_short average R^2 score: 0.6494112730026245
# dt_short R^2 score std: 0.10399336845187497
#
# param: (20, 3, 10, 100)
# dt_short rmse mean: 8.043001747131347
# dt_short rmse std: 1.277305837242485
# dt_short average R^2 score: 0.6514869928359985
# dt_short R^2 score std: 0.1032285971174637
#
# param: (20, 3, 10, 200)
# dt_short rmse mean: 8.079747867584228
# dt_short rmse std: 1.299700454233057
# dt_short average R^2 score: 0.6480011820793152
# dt_short R^2 score std: 0.10597213278493733
#
# param: (20, 3, 15, 100)
# dt_short rmse mean: 8.095910358428956
# dt_short rmse std: 1.32610537265256
# dt_short average R^2 score: 0.6462098360061646
# dt_short R^2 score std: 0.10887792976935819
#
# param: (20, 3, 15, 200)
# dt_short rmse mean: 8.110761356353759
# dt_short rmse std: 1.328934723378357
# dt_short average R^2 score: 0.6448668599128723
# dt_short R^2 score std: 0.10936899482378276
#
# param: (20, 3, 20, 100)
# dt_short rmse mean: 8.101428031921387
# dt_short rmse std: 1.323133001048349
# dt_short average R^2 score: 0.6457598328590393
# dt_short R^2 score std: 0.10861683145360515
#
# param: (20, 3, 20, 200)
# dt_short rmse mean: 8.114413928985595
# dt_short rmse std: 1.327421502009964
# dt_short average R^2 score: 0.6445531010627746
# dt_short R^2 score std: 0.10915442077285782
#
# param: (20, 5, 5, 100)
# dt_short rmse mean: 8.06712989807129
# dt_short rmse std: 1.2337538565988853
# dt_short average R^2 score: 0.6497833609580994
# dt_short R^2 score std: 0.10085483428717981
#
# param: (20, 5, 5, 200)
# dt_short rmse mean: 8.071647548675537
# dt_short rmse std: 1.2643883468015402
# dt_short average R^2 score: 0.6490757942199707
# dt_short R^2 score std: 0.10327004257011475
#
# param: (20, 5, 10, 100)
# dt_short rmse mean: 8.062733936309815
# dt_short rmse std: 1.3066236512860716
# dt_short average R^2 score: 0.6494268774986267
# dt_short R^2 score std: 0.10674414961707694
#
# param: (20, 5, 10, 200)
# dt_short rmse mean: 8.083404922485352
# dt_short rmse std: 1.3014306711119514
# dt_short average R^2 score: 0.6476837038993836
# dt_short R^2 score std: 0.10662553162605602
#
# param: (20, 5, 15, 100)
# dt_short rmse mean: 8.092394924163818
# dt_short rmse std: 1.3095622435603325
# dt_short average R^2 score: 0.6467596173286438
# dt_short R^2 score std: 0.10732460242353543
#
# param: (20, 5, 15, 200)
# dt_short rmse mean: 8.110475635528564
# dt_short rmse std: 1.3201272775053572
# dt_short average R^2 score: 0.6450334191322327
# dt_short R^2 score std: 0.10855859921776655
#
# param: (20, 5, 20, 100)
# dt_short rmse mean: 8.099950504302978
# dt_short rmse std: 1.3184620150189827
# dt_short average R^2 score: 0.6459873199462891
# dt_short R^2 score std: 0.10824830540688447
#
# param: (20, 5, 20, 200)
# dt_short rmse mean: 8.111628341674805
# dt_short rmse std: 1.3198258198038455
# dt_short average R^2 score: 0.6449303388595581
# dt_short R^2 score std: 0.10843546051481473
#
# param: (20, 10, 5, 100)
# dt_short rmse mean: 8.020254516601563
# dt_short rmse std: 1.2442818211877977
# dt_short average R^2 score: 0.6536398768424988
# dt_short R^2 score std: 0.10135421584349273
#
# param: (20, 10, 5, 200)
# dt_short rmse mean: 8.028358840942383
# dt_short rmse std: 1.2717346102932925
# dt_short average R^2 score: 0.6526795864105225
# dt_short R^2 score std: 0.1034187770680482
#
# param: (20, 10, 10, 100)
# dt_short rmse mean: 8.063169956207275
# dt_short rmse std: 1.2825963804501666
# dt_short average R^2 score: 0.6496519446372986
# dt_short R^2 score std: 0.10464847879080155
#
# param: (20, 10, 10, 200)
# dt_short rmse mean: 8.088082313537598
# dt_short rmse std: 1.3041582162963739
# dt_short average R^2 score: 0.6472033023834228
# dt_short R^2 score std: 0.10729269332259636
#
# param: (20, 10, 15, 100)
# dt_short rmse mean: 8.09743127822876
# dt_short rmse std: 1.3068108779757281
# dt_short average R^2 score: 0.6463539838790894
# dt_short R^2 score std: 0.10746113765850338
#
# param: (20, 10, 15, 200)
# dt_short rmse mean: 8.111422920227051
# dt_short rmse std: 1.3152294974291663
# dt_short average R^2 score: 0.6450095772743225
# dt_short R^2 score std: 0.1084048682754498
#
# param: (20, 10, 20, 100)
# dt_short rmse mean: 8.094638919830322
# dt_short rmse std: 1.3060721427000126
# dt_short average R^2 score: 0.6466190338134765
# dt_short R^2 score std: 0.10723253499498042
#
# param: (20, 10, 20, 200)
# dt_short rmse mean: 8.105445289611817
# dt_short rmse std: 1.3099750732310869
# dt_short average R^2 score: 0.6456172823905945
# dt_short R^2 score std: 0.10764125362304508
#
# param: (20, 20, 5, 100)
# dt_short rmse mean: 8.034628963470459
# dt_short rmse std: 1.2063403644468738
# dt_short average R^2 score: 0.652957534790039
# dt_short R^2 score std: 0.0975104833227683
#
# param: (20, 20, 5, 200)
# dt_short rmse mean: 8.036736392974854
# dt_short rmse std: 1.2384081895839538
# dt_short average R^2 score: 0.6523781061172486
# dt_short R^2 score std: 0.10045749030302144
#
# param: (20, 20, 10, 100)
# dt_short rmse mean: 8.054241371154784
# dt_short rmse std: 1.2873976848291857
# dt_short average R^2 score: 0.6503599524497986
# dt_short R^2 score std: 0.10540792234815816
#
# param: (20, 20, 10, 200)
# dt_short rmse mean: 8.067438316345214
# dt_short rmse std: 1.318823426783521
# dt_short average R^2 score: 0.6487950682640076
# dt_short R^2 score std: 0.10836339436786994
#
# param: (20, 20, 15, 100)
# dt_short rmse mean: 8.085223865509032
# dt_short rmse std: 1.3245229258032836
# dt_short average R^2 score: 0.6472410082817077
# dt_short R^2 score std: 0.1091892186552532
#
# param: (20, 20, 15, 200)
# dt_short rmse mean: 8.102384567260742
# dt_short rmse std: 1.324695782231103
# dt_short average R^2 score: 0.6456860542297364
# dt_short R^2 score std: 0.10953850509483874
#
# param: (20, 20, 20, 100)
# dt_short rmse mean: 8.088807296752929
# dt_short rmse std: 1.3114255680198683
# dt_short average R^2 score: 0.6470869064331055
# dt_short R^2 score std: 0.10793909899333513
#
# param: (20, 20, 20, 200)
# dt_short rmse mean: 8.105345916748046
# dt_short rmse std: 1.3160280342811352
# dt_short average R^2 score: 0.6455723524093628
# dt_short R^2 score std: 0.10868576090618343

# %%
print(best_loss, best_loss_param, best_R2, best_R2_param)
print([loss[best_loss_param, idx] for idx in range(5)])
print([R2_score[best_loss_param, idx] for idx in range(5)])

print([loss[best_R2_param, idx] for idx in range(5)])
print([R2_score[best_R2_param, idx] for idx in range(5)])
# Out:
# 6.815262794494629 (0, 0, 5, 100) 0.6536398768424988 (20, 10, 5, 100)
# [7.881916522979736, 9.021039962768555, 6.765152454376221, 9.922876358032227, 6.815262794494629]
# [0.6512922048568726, 0.6008128523826599, 0.7632182240486145, 0.4846162796020508, 0.7436041831970215]
# [7.952319622039795, 8.925756454467773, 6.681954860687256, 9.851795196533203, 6.689446449279785]
# [0.645034909248352, 0.6092010736465454, 0.7690063118934631, 0.4919736385345459, 0.7529834508895874]

# %% [markdown]
# A much better predictor, which is a good sign.

# %%
features = ['bunch', 'avg_wind_speed', 'avg_visibility', 'avg_health_index', 'rain', 'snow_on_ground', 'daylight', 'dir', 'stop']
tss = TimeSeriesSplit(n_splits=2, test_size=120)
tss_split = tss.split(daily_df, daily_df.date)
next(tss_split)
tss_train, tss_test = next(tss_split)

df_train = daily_df.iloc[tss_train]
df_test = daily_df.iloc[tss_test]

dt = 'dt_long'

model = xgb.XGBRegressor(objective='reg:squarederror',
                        n_estimators=200,
                        enable_categorical=True,
                        learning_rate=0.1,
                        max_depth=10,
                        reg_alpha=2,
                        reg_lambda=0,
                        seed=37)

X_train = df_train[features]
y_train = df_train[dt]


X_test = df_test[features]
y_test = df_test[dt]


model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred_train = model.predict(X_train)

df_pred = df_test.copy()
df_pred[dt] = y_pred


df_pred_train = df_train.copy()
df_pred_train[dt] = y_pred_train

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x=range(120), y=y_test)
sns.lineplot(x=range(120), y=y_pred)
